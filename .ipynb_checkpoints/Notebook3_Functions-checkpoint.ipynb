# %% [markdown]
# # References

# %% [markdown]
# Pandas:
#
# https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html
#
# https://pandas.pydata.org/docs/user_guide/timeseries.html

# %% [markdown]
# # import modules

# %%
# imports
import pandas as pd
import numpy as np

# full-width display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# pandas format
pd.set_option('display.float_format', '{:_.0f}'.format)
# NOTE: underscore separaters ('_') are better than commas (',') because 
# numbers with underscores work in Python without any extra effort.
pd.set_option('display.max_columns', None)

# plotting modules
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_theme()

import plotly.express as px
import plotly.graph_objects as go

import matplotlib as mpl
mpl.rcParams["axes.formatter.min_exponent"] = 20  # no scientific notation in graphs

# from matplotlib.ticker import MaxNLocator
# plt.rcParams['axes.titley'] = 1.0    # y is in axes-relative coordinates.
# plt.rcParams['axes.titlepad'] = 10   # pad is in points... default is 6
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# stop wrapping text in tables / dataframes

# %%
# %%html
# <style>.dataframe td {white-space: nowrap;}</style>
# Out:
# <style>.dataframe td {white-space: nowrap;}</style>

# %% [markdown]
# # import data

# %%
# NOTE this file IS NOT ON GITHUB, it is too big, so it is in gitignore
# run the RV Database notebook to create this file from the cleaned tables

# entire database in one dataframe (df for simplicity)
df = pd.read_csv(
    'RV_DATABASE.csv', 
    dtype={'MATURITY':object, 
           'STRAT':object, 
           'TOTNO':'Int64', 
           'SPEC':'Int64',
           'SPECIMEN_ID':'Int64'},
    parse_dates=['DATETIME']  # need to parse the DATETIME field as pd.datetime format
)

# sort by datetime and reindex
df = df.sort_values('DATETIME').reset_index(drop=True)

# %%
# individual tables used to define the database
SPECIES = pd.read_csv('SPECIES.csv', index_col = 'index')
SPECIES.columns = ['SPEC', 'COMMON_NAME', 'SCIENTIFIC_NAME']
MISSIONS = pd.read_csv('MISSIONS.csv')
GSCAT = pd.read_csv('GSCAT.csv')
GSINF = pd.read_csv('GSINF.csv', index_col='date and time', parse_dates=['date and time'])  # parse index as pd.datetime format
GSINF.index.name = 'DATETIME'
GSDET = pd.read_csv('GSDET.csv')

# %% [markdown]
# # Functions

# %%
def get_species(species_code):
    return SPECIES[SPECIES.SPEC == species_code].COMMON_NAME.tolist()[0]

# %%
def search_species_by_name(name_contains):
    """returns a list of species that fit the query"""
    return SPECIES[SPECIES['COMMON_NAME'].str.contains(name_contains, case=False)]
    
search_species_by_name('cod')
# Out:
#        SPEC       COMMON_NAME    SCIENTIFIC_NAME
# index
# 10       10     COD(ATLANTIC)       GADUS MORHUA
# 17       17  TOMCOD(ATLANTIC)  MICROGADUS TOMCOD
# 110     110        ARCTIC COD   BOREOGADUS SAIDA
# 118     118     GREENLAND COD         GADUS OGAC

# %% [markdown]
# ### Haul Weights, By Year or Month, by Species, with Graphs

# %%
# format dataframes
# could be improved, single function, loop through columns, look for 'PROP' etc, format 
# could deal with by_weight=True

def format_monthly(dataframe):
    return dataframe.style.format({
        'SPEC_TOTAL': '{:_.2f}'.format,
        'MONTH_TOTAL': '{:_.2f}'.format,
        'PROP_TOTAL': '{:.2%}'.format
    })

def format_yearly(dataframe):
    return dataframe.style.format({
        'SPEC_TOTAL': '{:_.2f}'.format,
        'YEAR_TOTAL': '{:_.2f}'.format,
        'PROP_TOTAL': '{:.2%}'.format
    })

# %%
def filtered_yearly(database, data_filter = None, by_weight=False):
    """
    assumes database is the main dataframe with the entire database
    data_filter needs the same dataframe name as database
        would be hard to repurpose this function, so not worth fixing
    data_filter is a boolean using the following syntax:
    data_filter = (database.DEPTH > 100) & (database.SPEED > 5) 
    """

    # total weight or total number?
    if by_weight == False:
        total_haul, total_to_drop = 'TOTNO', 'TOTWGT'
    else:
        total_haul, total_to_drop = 'TOTWGT', 'TOTNO'
    
    # columns to include
    columns = ['DATETIME', 'MISSION', 'SETNO', 'TOTWGT', 'TOTNO', 'SPEC', 'COMMON_NAME']

    # filter the data
    if type(data_filter) == type(None):
        haul_weights_filtered = database[columns].drop_duplicates()
    else:
        haul_weights_filtered = database[data_filter][columns].drop_duplicates()
      
    # weights by species
    yearly_weight_by_species = (
        haul_weights_filtered
        .drop(['SETNO', total_to_drop], axis=1)
        .groupby([haul_weights_filtered['DATETIME'].dt.year, 'SPEC']).sum()
    )
    yearly_weight_by_species = yearly_weight_by_species.reset_index(level=1)
    yearly_weight_by_species.index.names = ['YEAR']

    # total weights (filtered totals)
    yearly_weight_totals = (
        haul_weights_filtered
        .drop(['SETNO', total_to_drop, 'SPEC'], axis=1)
        .groupby([haul_weights_filtered['DATETIME'].dt.year]).sum()
    )
    yearly_weight_totals.index.names = ['YEAR']

    # join the two dataframes
    yearly_weight_by_species = (
        yearly_weight_by_species
        .merge(yearly_weight_totals, how='outer', on=['YEAR'])
        .rename(columns={f'{total_haul}_x': 'SPEC_TOTAL', f'{total_haul}_y': 'YEAR_TOTAL'})
    )

    # calculate the proportion of species to the total
    yearly_weight_by_species['PROP_TOTAL'] = (
        yearly_weight_by_species['SPEC_TOTAL'] / yearly_weight_by_species['YEAR_TOTAL']
    )

    return yearly_weight_by_species

# %%
def filtered_monthly(database, data_filter = None, by_weight=False):
    """
    assumes database is the main dataframe with the entire database
    data_filter needs the same dataframe name as database
        would be hard to repurpose this function, so not worth fixing
    data_filter is a boolean using the following syntax:
    data_filter = (database.DEPTH > 100) & (database.SPEED > 5) 
    """
    # total weight or total number?
    if by_weight == False:
        total_haul, total_to_drop = 'TOTNO', 'TOTWGT'
    else:
        total_haul, total_to_drop = 'TOTWGT', 'TOTNO'
    
    # columns to include
    columns = ['DATETIME', 'MISSION', 'SETNO', 'TOTWGT', 'TOTNO', 'SPEC', 'COMMON_NAME']

    # filter the data
    if type(data_filter) == type(None):
        haul_weights_filtered = database[columns].drop_duplicates()
    else:
        haul_weights_filtered = database[data_filter][columns].drop_duplicates()
      
    # weights by species
    monthly_weight_by_species = (
        haul_weights_filtered
        .drop(['SETNO', total_to_drop], axis=1)
        .groupby([haul_weights_filtered['DATETIME'].dt.year, haul_weights_filtered['DATETIME'].dt.month, 'SPEC']).sum()
    )
    monthly_weight_by_species = monthly_weight_by_species.reset_index(level=2)
    monthly_weight_by_species.index.names = ['YEAR', 'MONTH']

    # total weights (filtered totals)
    monthly_weight_totals = (
        haul_weights_filtered
        .drop(['SETNO', total_to_drop, 'SPEC'], axis=1)
        .groupby([haul_weights_filtered['DATETIME'].dt.year, haul_weights_filtered['DATETIME'].dt.month]).sum()
    )
    monthly_weight_totals.index.names = ['YEAR', 'MONTH']

    # join the two dataframes
    monthly_weight_by_species = monthly_weight_by_species
    monthly_weight_by_species = (
        monthly_weight_by_species
        .merge(monthly_weight_totals, how='outer', on=['YEAR', 'MONTH'])
        .rename(columns={f'{total_haul}_x': 'SPEC_TOTAL', f'{total_haul}_y': 'MONTH_TOTAL'})
    )

    # calculate the proportion of species to the total
    monthly_weight_by_species['PROP_TOTAL'] = (
        monthly_weight_by_species['SPEC_TOTAL'] / monthly_weight_by_species['MONTH_TOTAL']
    )

    return monthly_weight_by_species

# %%
def filter_by_species(dataframe, species_code):
    dataframe = dataframe[dataframe.SPEC == species_code].copy()
    dataframe.drop('SPEC', axis=1, inplace=True)  # remove SPEC label
    return dataframe

# %%
def graph_species(dataframe, species_code, title=None, ylabel=None):
    """
    takes in an unfiltered dataframe, filters it, and plots the data
    """
    
    # species input
    spec_no = species_code
    species = get_species(spec_no)
    
    # filter the data
    filtered_data = filter_by_species(dataframe, spec_no)
    
    # label overrides
    if title == None:
        title=f'Proportion of Haul. Species: {species}.'
    if ylabel == None:
        ylabel='Proportion of Total'
    
    # graph the proportion of haul by species by year
    dataframe[dataframe.SPEC == spec_no].plot(
        kind='bar',
        width=1,
        y='PROP_TOTAL', 
        ylabel=ylabel,
        figsize=(30, 8), 
        legend=False, 
        title=title
    );

# %% [markdown]
# ### Testine Filtering and Graphing

# %%
filtered_monthly(df).head()
# Out:
#             SPEC  SPEC_TOTAL  MONTH_TOTAL  PROP_TOTAL
# YEAR MONTH
# 1970 7        10        2086        48872           0
#      7        11        2166        48872           0
#      7        12         790        48872           0
#      7        13          20        48872           0
#      7        14        3106        48872           0

# %%
filtered_yearly(df).head()
# Out:
#       SPEC  SPEC_TOTAL  YEAR_TOTAL  PROP_TOTAL
# YEAR
# 1970    10        2086       48872           0
# 1970    11        2166       48872           0
# 1970    12         790       48872           0
# 1970    13          20       48872           0
# 1970    14        3106       48872           0

# %%
filter_by_species(filtered_yearly(df), 10).head()
# Out:
#       SPEC_TOTAL  YEAR_TOTAL  PROP_TOTAL
# YEAR
# 1970        2086       48872           0
# 1971        2058       39202           0
# 1972        2034       52241           0
# 1973        5869       42214           0
# 1974        3128       44950           0

# %%
graph_species(filtered_monthly(df), 10)

# %%
graph_species(filtered_monthly(df, by_weight=True), 10)

# %%
graph_species(filtered_yearly(df), 10)

# %%
graph_species(filtered_yearly(df, by_weight=True), 10)

# %%
# check filter works
data_filter = (df.DEPTH > 100)
graph_species(filtered_monthly(df, data_filter), 10)

# %%
# check filter works
data_filter = (df.DEPTH > 100)
graph_species(filtered_yearly(df, data_filter), 602)

# %%
# which months were this super deep eel caught?
graph_species(filtered_monthly(df, df.DEPTH > 1000), 602)

# %%
# check percentages
data_filter = (df.DEPTH > 1800)
test = filtered_monthly(df, data_filter)
year_month = (2010, 8)
print(test[test.index == year_month].PROP_TOTAL.sum())
print()
format_monthly(test[test.index == year_month].sort_values('PROP_TOTAL', ascending=False).head(10))
# Out:
# 1.0
# <style type="text/css">
# </style>
# <table id="T_ed7a4_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SPEC</th>
#       <th class="col_heading level0 col1" >SPEC_TOTAL</th>
#       <th class="col_heading level0 col2" >MONTH_TOTAL</th>
#       <th class="col_heading level0 col3" >PROP_TOTAL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th class="index_name level1" >MONTH</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed7a4_level0_row0" class="row_heading level0 row0" rowspan="10">2010</th>
#       <th id="T_ed7a4_level1_row0" class="row_heading level1 row0" >8</th>
#       <td id="T_ed7a4_row0_col0" class="data row0 col0" >8353</td>
#       <td id="T_ed7a4_row0_col1" class="data row0 col1" >37.00</td>
#       <td id="T_ed7a4_row0_col2" class="data row0 col2" >201.00</td>
#       <td id="T_ed7a4_row0_col3" class="data row0 col3" >18.41%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row1" class="row_heading level1 row1" >8</th>
#       <td id="T_ed7a4_row1_col0" class="data row1 col0" >157</td>
#       <td id="T_ed7a4_row1_col1" class="data row1 col1" >23.00</td>
#       <td id="T_ed7a4_row1_col2" class="data row1 col2" >201.00</td>
#       <td id="T_ed7a4_row1_col3" class="data row1 col3" >11.44%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row2" class="row_heading level1 row2" >8</th>
#       <td id="T_ed7a4_row2_col0" class="data row2 col0" >146</td>
#       <td id="T_ed7a4_row2_col1" class="data row2 col1" >15.00</td>
#       <td id="T_ed7a4_row2_col2" class="data row2 col2" >201.00</td>
#       <td id="T_ed7a4_row2_col3" class="data row2 col3" >7.46%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row3" class="row_heading level1 row3" >8</th>
#       <td id="T_ed7a4_row3_col0" class="data row3 col0" >613</td>
#       <td id="T_ed7a4_row3_col1" class="data row3 col1" >11.00</td>
#       <td id="T_ed7a4_row3_col2" class="data row3 col2" >201.00</td>
#       <td id="T_ed7a4_row3_col3" class="data row3 col3" >5.47%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row4" class="row_heading level1 row4" >8</th>
#       <td id="T_ed7a4_row4_col0" class="data row4 col0" >9992</td>
#       <td id="T_ed7a4_row4_col1" class="data row4 col1" >10.00</td>
#       <td id="T_ed7a4_row4_col2" class="data row4 col2" >201.00</td>
#       <td id="T_ed7a4_row4_col3" class="data row4 col3" >4.98%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row5" class="row_heading level1 row5" >8</th>
#       <td id="T_ed7a4_row5_col0" class="data row5 col0" >8500</td>
#       <td id="T_ed7a4_row5_col1" class="data row5 col1" >9.00</td>
#       <td id="T_ed7a4_row5_col2" class="data row5 col2" >201.00</td>
#       <td id="T_ed7a4_row5_col3" class="data row5 col3" >4.48%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row6" class="row_heading level1 row6" >8</th>
#       <td id="T_ed7a4_row6_col0" class="data row6 col0" >749</td>
#       <td id="T_ed7a4_row6_col1" class="data row6 col1" >9.00</td>
#       <td id="T_ed7a4_row6_col2" class="data row6 col2" >201.00</td>
#       <td id="T_ed7a4_row6_col3" class="data row6 col3" >4.48%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row7" class="row_heading level1 row7" >8</th>
#       <td id="T_ed7a4_row7_col0" class="data row7 col0" >795</td>
#       <td id="T_ed7a4_row7_col1" class="data row7 col1" >8.00</td>
#       <td id="T_ed7a4_row7_col2" class="data row7 col2" >201.00</td>
#       <td id="T_ed7a4_row7_col3" class="data row7 col3" >3.98%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_ed7a4_row8_col0" class="data row8 col0" >159</td>
#       <td id="T_ed7a4_row8_col1" class="data row8 col1" >7.00</td>
#       <td id="T_ed7a4_row8_col2" class="data row8 col2" >201.00</td>
#       <td id="T_ed7a4_row8_col3" class="data row8 col3" >3.48%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7a4_level1_row9" class="row_heading level1 row9" >8</th>
#       <td id="T_ed7a4_row9_col0" class="data row9 col0" >602</td>
#       <td id="T_ed7a4_row9_col1" class="data row9 col1" >7.00</td>
#       <td id="T_ed7a4_row9_col2" class="data row9 col2" >201.00</td>
#       <td id="T_ed7a4_row9_col3" class="data row9 col3" >3.48%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# check percentages
data_filter = (df.DEPTH > 1800)
test = filtered_monthly(df, data_filter, by_weight=True)
year_month = (2010, 8)
print(test[test.index == year_month].PROP_TOTAL.sum())
print()
format_monthly(test[test.index == year_month].sort_values('PROP_TOTAL', ascending=False).head(10))
# Out:
# 1.0000000000000002
# <style type="text/css">
# </style>
# <table id="T_79698_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SPEC</th>
#       <th class="col_heading level0 col1" >SPEC_TOTAL</th>
#       <th class="col_heading level0 col2" >MONTH_TOTAL</th>
#       <th class="col_heading level0 col3" >PROP_TOTAL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th class="index_name level1" >MONTH</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79698_level0_row0" class="row_heading level0 row0" rowspan="10">2010</th>
#       <th id="T_79698_level1_row0" class="row_heading level1 row0" >8</th>
#       <td id="T_79698_row0_col0" class="data row0 col0" >113</td>
#       <td id="T_79698_row0_col1" class="data row0 col1" >2.23</td>
#       <td id="T_79698_row0_col2" class="data row0 col2" >9.49</td>
#       <td id="T_79698_row0_col3" class="data row0 col3" >23.49%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row1" class="row_heading level1 row1" >8</th>
#       <td id="T_79698_row1_col0" class="data row1 col0" >1028</td>
#       <td id="T_79698_row1_col1" class="data row1 col1" >1.86</td>
#       <td id="T_79698_row1_col2" class="data row1 col2" >9.49</td>
#       <td id="T_79698_row1_col3" class="data row1 col3" >19.59%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row2" class="row_heading level1 row2" >8</th>
#       <td id="T_79698_row2_col0" class="data row2 col0" >749</td>
#       <td id="T_79698_row2_col1" class="data row2 col1" >1.42</td>
#       <td id="T_79698_row2_col2" class="data row2 col2" >9.49</td>
#       <td id="T_79698_row2_col3" class="data row2 col3" >14.96%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row3" class="row_heading level1 row3" >8</th>
#       <td id="T_79698_row3_col0" class="data row3 col0" >9997</td>
#       <td id="T_79698_row3_col1" class="data row3 col1" >0.99</td>
#       <td id="T_79698_row3_col2" class="data row3 col2" >9.49</td>
#       <td id="T_79698_row3_col3" class="data row3 col3" >10.43%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row4" class="row_heading level1 row4" >8</th>
#       <td id="T_79698_row4_col0" class="data row4 col0" >8500</td>
#       <td id="T_79698_row4_col1" class="data row4 col1" >0.53</td>
#       <td id="T_79698_row4_col2" class="data row4 col2" >9.49</td>
#       <td id="T_79698_row4_col3" class="data row4 col3" >5.56%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row5" class="row_heading level1 row5" >8</th>
#       <td id="T_79698_row5_col0" class="data row5 col0" >6400</td>
#       <td id="T_79698_row5_col1" class="data row5 col1" >0.42</td>
#       <td id="T_79698_row5_col2" class="data row5 col2" >9.49</td>
#       <td id="T_79698_row5_col3" class="data row5 col3" >4.44%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row6" class="row_heading level1 row6" >8</th>
#       <td id="T_79698_row6_col0" class="data row6 col0" >613</td>
#       <td id="T_79698_row6_col1" class="data row6 col1" >0.38</td>
#       <td id="T_79698_row6_col2" class="data row6 col2" >9.49</td>
#       <td id="T_79698_row6_col3" class="data row6 col3" >3.98%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row7" class="row_heading level1 row7" >8</th>
#       <td id="T_79698_row7_col0" class="data row7 col0" >602</td>
#       <td id="T_79698_row7_col1" class="data row7 col1" >0.27</td>
#       <td id="T_79698_row7_col2" class="data row7 col2" >9.49</td>
#       <td id="T_79698_row7_col3" class="data row7 col3" >2.84%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_79698_row8_col0" class="data row8 col0" >795</td>
#       <td id="T_79698_row8_col1" class="data row8 col1" >0.26</td>
#       <td id="T_79698_row8_col2" class="data row8 col2" >9.49</td>
#       <td id="T_79698_row8_col3" class="data row8 col3" >2.76%</td>
#     </tr>
#     <tr>
#       <th id="T_79698_level1_row9" class="row_heading level1 row9" >8</th>
#       <td id="T_79698_row9_col0" class="data row9 col0" >9992</td>
#       <td id="T_79698_row9_col1" class="data row9 col1" >0.18</td>
#       <td id="T_79698_row9_col2" class="data row9 col2" >9.49</td>
#       <td id="T_79698_row9_col3" class="data row9 col3" >1.92%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Descriptive Statistics Function

# %%
def describe_species_all(dataframe, species_code):
    """descriptive stats for all columns. Many NaN with this method"""
    
    all_columns = ['SPEC', 'COMMON_NAME', 'SCIENTIFIC_NAME', 'FLEN', 'FWT', 'AGE',
        'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL',
        'MATURITY', 'SEX', 'STRAT']  # object columns

    df_all = dataframe[all_columns][dataframe.SPEC == species_code]

    # count row is dropped for display purposes, but may be useful
    return df_all.describe(include='all').drop('count') 

describe_species_all(df, 10)
# Out:
#         SPEC    COMMON_NAME SCIENTIFIC_NAME  FLEN    FWT  AGE  SLAT  SLONG  \
# unique   NaN              1               1   NaN    NaN  NaN   NaN    NaN
# top      NaN  COD(ATLANTIC)    GADUS MORHUA   NaN    NaN  NaN   NaN    NaN
# freq     NaN         119753          119753   NaN    NaN  NaN   NaN    NaN
# mean      10            NaN             NaN    50  1_807    4    44    -63
# std        0            NaN             NaN    19  2_227    2     1      3
# min       10            NaN             NaN     2      0    0    40    -70
# 25%       10            NaN             NaN    37    492    3    43    -66
# 50%       10            NaN             NaN    49  1_120    4    44    -61
# 75%       10            NaN             NaN    61  2_200    5    45    -60
# max       10            NaN             NaN   161 38_000   20    48    -57
#
#         ELAT  ELONG  DEPTH  SURF_TEMP  BOTT_TEMP  BOTT_SAL MATURITY     SEX  \
# unique   NaN    NaN    NaN        NaN        NaN       NaN        9       4
# top      NaN    NaN    NaN        NaN        NaN       NaN  Resting  FEMALE
# freq     NaN    NaN    NaN        NaN        NaN       NaN    21151   48968
# mean      43    -63    105         11          5        33      NaN     NaN
# std        2      3     58          6          3         1      NaN     NaN
# min       40    -70     22         -2         -2       -99      NaN     NaN
# 25%       42    -66     68          5          3        32      NaN     NaN
# 50%       43    -66     86         12          5        33      NaN     NaN
# 75%       45    -60    130         15          6        33      NaN     NaN
# max       47    -57    507         22         17        36      NaN     NaN
#
#         STRAT
# unique     86
# top       5Z2
# freq    18105
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
def describe_species(dataframe, species_code):
    """descriptive stats for numeric columns"""
    
    numeric_columns = ['SPEC', 'COMMON_NAME', 'SCIENTIFIC_NAME', 'FLEN', 'FWT', 'AGE',
        'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL']

    df_numeric = dataframe[numeric_columns][dataframe.SPEC == species_code]

    # count row is dropped for display purposes, but may be useful
    return df_numeric.describe().drop('count')

# describe_species(df, 10)


def species_counts(dataframe, species_code):
    """for object data that won't appear in df.describe() along with numeric fields"""
        
    object_columns = ['MATURITY', 'SEX', 'STRAT']
    df_object = dataframe[object_columns][dataframe.SPEC == species_code]
    
    dict_of_unique = {}
    
    for i in object_columns:
        dict_of_unique[i] = df_object[i].value_counts()
    
    return dict_of_unique

# species_counts(df, 10)


def print_species_data(dataframe, species_code):
    
    print('\n', get_species(species_code))
    
    df_describe = describe_species(dataframe, species_code)
    df_count = species_counts(dataframe, species_code)
    
    # display numeric data
    display(df_describe.drop('SPEC', axis=1).style.format({
        'FLEN': '{:_.2f}'.format,
        'FWT': '{:_.2f}'.format,
        'AGE': '{:_.2f}'.format,
        'DEPTH': '{:_.2f}'.format,
        'SURF_TEMP': '{:_.2f}'.format,
        'BOTT_TEMP': '{:_.2f}'.format,
        'BOTT_SAL': '{:_.2f}'.format,
        'SLONG': '{:_.5f}'.format,
        'SLAT': '{:_.5f}'.format
    }))
    
    # display object counts
    for key in df_count.keys():
        display(pd.DataFrame(df_count[key]))
    
# print_species_data(df, 10)

# %% [markdown]
# ### Testing Descriptive Statistics

# %%
print_species_data(df, 10)
# Out:
#  COD(ATLANTIC)
# <style type="text/css">
# </style>
# <table id="T_04be1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >FLEN</th>
#       <th class="col_heading level0 col1" >FWT</th>
#       <th class="col_heading level0 col2" >AGE</th>
#       <th class="col_heading level0 col3" >SLAT</th>
#       <th class="col_heading level0 col4" >SLONG</th>
#       <th class="col_heading level0 col5" >ELAT</th>
#       <th class="col_heading level0 col6" >ELONG</th>
#       <th class="col_heading level0 col7" >DEPTH</th>
#       <th class="col_heading level0 col8" >SURF_TEMP</th>
#       <th class="col_heading level0 col9" >BOTT_TEMP</th>
#       <th class="col_heading level0 col10" >BOTT_SAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04be1_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_04be1_row0_col0" class="data row0 col0" >49.67</td>
#       <td id="T_04be1_row0_col1" class="data row0 col1" >1_806.80</td>
#       <td id="T_04be1_row0_col2" class="data row0 col2" >4.09</td>
#       <td id="T_04be1_row0_col3" class="data row0 col3" >43.88246</td>
#       <td id="T_04be1_row0_col4" class="data row0 col4" >-62.51333</td>
#       <td id="T_04be1_row0_col5" class="data row0 col5" >43.444762</td>
#       <td id="T_04be1_row0_col6" class="data row0 col6" >-63.450219</td>
#       <td id="T_04be1_row0_col7" class="data row0 col7" >104.73</td>
#       <td id="T_04be1_row0_col8" class="data row0 col8" >10.63</td>
#       <td id="T_04be1_row0_col9" class="data row0 col9" >4.87</td>
#       <td id="T_04be1_row0_col10" class="data row0 col10" >32.93</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_04be1_row1_col0" class="data row1 col0" >18.81</td>
#       <td id="T_04be1_row1_col1" class="data row1 col1" >2_226.74</td>
#       <td id="T_04be1_row1_col2" class="data row1 col2" >2.00</td>
#       <td id="T_04be1_row1_col3" class="data row1 col3" >1.47821</td>
#       <td id="T_04be1_row1_col4" class="data row1 col4" >3.40791</td>
#       <td id="T_04be1_row1_col5" class="data row1 col5" >1.601751</td>
#       <td id="T_04be1_row1_col6" class="data row1 col6" >3.495063</td>
#       <td id="T_04be1_row1_col7" class="data row1 col7" >57.68</td>
#       <td id="T_04be1_row1_col8" class="data row1 col8" >5.76</td>
#       <td id="T_04be1_row1_col9" class="data row1 col9" >2.51</td>
#       <td id="T_04be1_row1_col10" class="data row1 col10" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_04be1_row2_col0" class="data row2 col0" >2.00</td>
#       <td id="T_04be1_row2_col1" class="data row2 col1" >0.30</td>
#       <td id="T_04be1_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_04be1_row2_col3" class="data row2 col3" >40.31850</td>
#       <td id="T_04be1_row2_col4" class="data row2 col4" >-69.98167</td>
#       <td id="T_04be1_row2_col5" class="data row2 col5" >40.297833</td>
#       <td id="T_04be1_row2_col6" class="data row2 col6" >-69.970000</td>
#       <td id="T_04be1_row2_col7" class="data row2 col7" >21.95</td>
#       <td id="T_04be1_row2_col8" class="data row2 col8" >-1.68</td>
#       <td id="T_04be1_row2_col9" class="data row2 col9" >-1.53</td>
#       <td id="T_04be1_row2_col10" class="data row2 col10" >-99.00</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_04be1_row3_col0" class="data row3 col0" >37.00</td>
#       <td id="T_04be1_row3_col1" class="data row3 col1" >492.00</td>
#       <td id="T_04be1_row3_col2" class="data row3 col2" >3.00</td>
#       <td id="T_04be1_row3_col3" class="data row3 col3" >42.63333</td>
#       <td id="T_04be1_row3_col4" class="data row3 col4" >-66.22800</td>
#       <td id="T_04be1_row3_col5" class="data row3 col5" >41.974167</td>
#       <td id="T_04be1_row3_col6" class="data row3 col6" >-66.459833</td>
#       <td id="T_04be1_row3_col7" class="data row3 col7" >67.67</td>
#       <td id="T_04be1_row3_col8" class="data row3 col8" >4.90</td>
#       <td id="T_04be1_row3_col9" class="data row3 col9" >3.03</td>
#       <td id="T_04be1_row3_col10" class="data row3 col10" >32.38</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_04be1_row4_col0" class="data row4 col0" >49.00</td>
#       <td id="T_04be1_row4_col1" class="data row4 col1" >1_120.00</td>
#       <td id="T_04be1_row4_col2" class="data row4 col2" >4.00</td>
#       <td id="T_04be1_row4_col3" class="data row4 col3" >44.03333</td>
#       <td id="T_04be1_row4_col4" class="data row4 col4" >-61.16667</td>
#       <td id="T_04be1_row4_col5" class="data row4 col5" >43.394833</td>
#       <td id="T_04be1_row4_col6" class="data row4 col6" >-65.578833</td>
#       <td id="T_04be1_row4_col7" class="data row4 col7" >85.95</td>
#       <td id="T_04be1_row4_col8" class="data row4 col8" >12.50</td>
#       <td id="T_04be1_row4_col9" class="data row4 col9" >4.67</td>
#       <td id="T_04be1_row4_col10" class="data row4 col10" >32.85</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_04be1_row5_col0" class="data row5 col0" >61.00</td>
#       <td id="T_04be1_row5_col1" class="data row5 col1" >2_200.00</td>
#       <td id="T_04be1_row5_col2" class="data row5 col2" >5.00</td>
#       <td id="T_04be1_row5_col3" class="data row5 col3" >44.83800</td>
#       <td id="T_04be1_row5_col4" class="data row5 col4" >-59.51667</td>
#       <td id="T_04be1_row5_col5" class="data row5 col5" >44.537500</td>
#       <td id="T_04be1_row5_col6" class="data row5 col6" >-60.119000</td>
#       <td id="T_04be1_row5_col7" class="data row5 col7" >129.84</td>
#       <td id="T_04be1_row5_col8" class="data row5 col8" >15.30</td>
#       <td id="T_04be1_row5_col9" class="data row5 col9" >6.41</td>
#       <td id="T_04be1_row5_col10" class="data row5 col10" >33.40</td>
#     </tr>
#     <tr>
#       <th id="T_04be1_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_04be1_row6_col0" class="data row6 col0" >161.00</td>
#       <td id="T_04be1_row6_col1" class="data row6 col1" >38_000.00</td>
#       <td id="T_04be1_row6_col2" class="data row6 col2" >20.00</td>
#       <td id="T_04be1_row6_col3" class="data row6 col3" >47.85000</td>
#       <td id="T_04be1_row6_col4" class="data row6 col4" >-56.55800</td>
#       <td id="T_04be1_row6_col5" class="data row6 col5" >47.189000</td>
#       <td id="T_04be1_row6_col6" class="data row6 col6" >-56.539667</td>
#       <td id="T_04be1_row6_col7" class="data row6 col7" >507.49</td>
#       <td id="T_04be1_row6_col8" class="data row6 col8" >21.84</td>
#       <td id="T_04be1_row6_col9" class="data row6 col9" >16.70</td>
#       <td id="T_04be1_row6_col10" class="data row6 col10" >35.56</td>
#     </tr>
#   </tbody>
# </table>
#                     MATURITY
# Resting                21151
# Immature               20899
# Recovering              8248
# Ripening 1              6871
# Ripening 2              5125
# Spent                   4323
# Ripe (Mature)           3581
# Spawning (Running)      3439
# Undetermined              27
#                   SEX
# FEMALE          48968
# MALE            48683
# UNKNOWN         10586
# BERRIED FEMALE      2
#      STRAT
# 5Z2  18105
# 441   7507
# 455   7397
# 444   4870
# 447   4765
# ..     ...
# 439      4
# 396      4
# 5Z8      3
# 436      2
# 434      2
#
# [86 rows x 1 columns]

# %%
print_species_data(df, 602)
# Out:
#  GRAY'S CUTTHROAT EEL
# <style type="text/css">
# </style>
# <table id="T_1ae00_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >FLEN</th>
#       <th class="col_heading level0 col1" >FWT</th>
#       <th class="col_heading level0 col2" >AGE</th>
#       <th class="col_heading level0 col3" >SLAT</th>
#       <th class="col_heading level0 col4" >SLONG</th>
#       <th class="col_heading level0 col5" >ELAT</th>
#       <th class="col_heading level0 col6" >ELONG</th>
#       <th class="col_heading level0 col7" >DEPTH</th>
#       <th class="col_heading level0 col8" >SURF_TEMP</th>
#       <th class="col_heading level0 col9" >BOTT_TEMP</th>
#       <th class="col_heading level0 col10" >BOTT_SAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ae00_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_1ae00_row0_col0" class="data row0 col0" >43.17</td>
#       <td id="T_1ae00_row0_col1" class="data row0 col1" >75.69</td>
#       <td id="T_1ae00_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_1ae00_row0_col3" class="data row0 col3" >42.86308</td>
#       <td id="T_1ae00_row0_col4" class="data row0 col4" >-62.59036</td>
#       <td id="T_1ae00_row0_col5" class="data row0 col5" >42.863599</td>
#       <td id="T_1ae00_row0_col6" class="data row0 col6" >-62.602674</td>
#       <td id="T_1ae00_row0_col7" class="data row0 col7" >976.90</td>
#       <td id="T_1ae00_row0_col8" class="data row0 col8" >15.35</td>
#       <td id="T_1ae00_row0_col9" class="data row0 col9" >5.20</td>
#       <td id="T_1ae00_row0_col10" class="data row0 col10" >34.93</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_1ae00_row1_col0" class="data row1 col0" >10.50</td>
#       <td id="T_1ae00_row1_col1" class="data row1 col1" >62.05</td>
#       <td id="T_1ae00_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_1ae00_row1_col3" class="data row1 col3" >0.50209</td>
#       <td id="T_1ae00_row1_col4" class="data row1 col4" >1.75039</td>
#       <td id="T_1ae00_row1_col5" class="data row1 col5" >0.493916</td>
#       <td id="T_1ae00_row1_col6" class="data row1 col6" >1.727133</td>
#       <td id="T_1ae00_row1_col7" class="data row1 col7" >368.53</td>
#       <td id="T_1ae00_row1_col8" class="data row1 col8" >3.52</td>
#       <td id="T_1ae00_row1_col9" class="data row1 col9" >0.86</td>
#       <td id="T_1ae00_row1_col10" class="data row1 col10" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_1ae00_row2_col0" class="data row2 col0" >9.00</td>
#       <td id="T_1ae00_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_1ae00_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_1ae00_row2_col3" class="data row2 col3" >40.06983</td>
#       <td id="T_1ae00_row2_col4" class="data row2 col4" >-69.97417</td>
#       <td id="T_1ae00_row2_col5" class="data row2 col5" >40.097000</td>
#       <td id="T_1ae00_row2_col6" class="data row2 col6" >-69.978667</td>
#       <td id="T_1ae00_row2_col7" class="data row2 col7" >76.81</td>
#       <td id="T_1ae00_row2_col8" class="data row2 col8" >-0.50</td>
#       <td id="T_1ae00_row2_col9" class="data row2 col9" >4.28</td>
#       <td id="T_1ae00_row2_col10" class="data row2 col10" >33.61</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_1ae00_row3_col0" class="data row3 col0" >35.00</td>
#       <td id="T_1ae00_row3_col1" class="data row3 col1" >28.00</td>
#       <td id="T_1ae00_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_1ae00_row3_col3" class="data row3 col3" >42.64917</td>
#       <td id="T_1ae00_row3_col4" class="data row3 col4" >-63.86617</td>
#       <td id="T_1ae00_row3_col5" class="data row3 col5" >42.648500</td>
#       <td id="T_1ae00_row3_col6" class="data row3 col6" >-63.881833</td>
#       <td id="T_1ae00_row3_col7" class="data row3 col7" >642.82</td>
#       <td id="T_1ae00_row3_col8" class="data row3 col8" >14.56</td>
#       <td id="T_1ae00_row3_col9" class="data row3 col9" >4.63</td>
#       <td id="T_1ae00_row3_col10" class="data row3 col10" >34.92</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_1ae00_row4_col0" class="data row4 col0" >42.00</td>
#       <td id="T_1ae00_row4_col1" class="data row4 col1" >54.00</td>
#       <td id="T_1ae00_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_1ae00_row4_col3" class="data row4 col3" >42.71267</td>
#       <td id="T_1ae00_row4_col4" class="data row4 col4" >-63.37733</td>
#       <td id="T_1ae00_row4_col5" class="data row4 col5" >42.713500</td>
#       <td id="T_1ae00_row4_col6" class="data row4 col6" >-63.303167</td>
#       <td id="T_1ae00_row4_col7" class="data row4 col7" >908.00</td>
#       <td id="T_1ae00_row4_col8" class="data row4 col8" >15.63</td>
#       <td id="T_1ae00_row4_col9" class="data row4 col9" >4.92</td>
#       <td id="T_1ae00_row4_col10" class="data row4 col10" >34.94</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_1ae00_row5_col0" class="data row5 col0" >51.00</td>
#       <td id="T_1ae00_row5_col1" class="data row5 col1" >110.00</td>
#       <td id="T_1ae00_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_1ae00_row5_col3" class="data row5 col3" >42.84500</td>
#       <td id="T_1ae00_row5_col4" class="data row5 col4" >-62.01133</td>
#       <td id="T_1ae00_row5_col5" class="data row5 col5" >42.845167</td>
#       <td id="T_1ae00_row5_col6" class="data row5 col6" >-61.940000</td>
#       <td id="T_1ae00_row5_col7" class="data row5 col7" >1_313.99</td>
#       <td id="T_1ae00_row5_col8" class="data row5 col8" >17.30</td>
#       <td id="T_1ae00_row5_col9" class="data row5 col9" >5.24</td>
#       <td id="T_1ae00_row5_col10" class="data row5 col10" >34.97</td>
#     </tr>
#     <tr>
#       <th id="T_1ae00_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_1ae00_row6_col0" class="data row6 col0" >76.00</td>
#       <td id="T_1ae00_row6_col1" class="data row6 col1" >450.00</td>
#       <td id="T_1ae00_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_1ae00_row6_col3" class="data row6 col3" >45.52283</td>
#       <td id="T_1ae00_row6_col4" class="data row6 col4" >-56.95250</td>
#       <td id="T_1ae00_row6_col5" class="data row6 col5" >45.515833</td>
#       <td id="T_1ae00_row6_col6" class="data row6 col6" >-56.928000</td>
#       <td id="T_1ae00_row6_col7" class="data row6 col7" >1_805.94</td>
#       <td id="T_1ae00_row6_col8" class="data row6 col8" >20.97</td>
#       <td id="T_1ae00_row6_col9" class="data row6 col9" >10.77</td>
#       <td id="T_1ae00_row6_col10" class="data row6 col10" >35.17</td>
#     </tr>
#   </tbody>
# </table>
#               MATURITY
# Undetermined        20
#          SEX
# UNKNOWN   41
#      STRAT
# 501    343
# 502    340
# 498    328
# 503    319
# 504    193
# 497    156
# 496    134
# 397     12
# 451      8
# 404      7
# 505      7
# 398      3
# 466      2
# 5Z8      2
# 478      1
# 5Z4      1
# 400      1
# 472      1
# 399      1
# 462      1
# 559      1

# %% [markdown]
# # Mapping and Visualisation Functions

# %% [markdown]
# ### checking whether to interpolate, average, or draw a line

# %%
# check variance in SLONG vs ELONG and SLAT vs ELAT
# should we take an average, use both, use one?

geo_columns = ['SLONG', 'ELONG', 'SLAT', 'ELAT']

df_geo = df[geo_columns].copy()
df_geo['LONG_DIFF'] = df_geo['ELONG'] - df_geo['SLONG'] 
df_geo['LAT_DIFF'] = df_geo['ELAT'] - df_geo['SLAT'] 

df_geo[['LONG_DIFF', 'LAT_DIFF']].describe().style.format()
# Out:
# <style type="text/css">
# </style>
# <table id="T_787a2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >LONG_DIFF</th>
#       <th class="col_heading level0 col1" >LAT_DIFF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_787a2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_787a2_row0_col0" class="data row0 col0" >1726156.000000</td>
#       <td id="T_787a2_row0_col1" class="data row0 col1" >1726156.000000</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_787a2_row1_col0" class="data row1 col0" >0.000869</td>
#       <td id="T_787a2_row1_col1" class="data row1 col1" >0.000029</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_787a2_row2_col0" class="data row2 col0" >0.028723</td>
#       <td id="T_787a2_row2_col1" class="data row2 col1" >0.020090</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_787a2_row3_col0" class="data row3 col0" >-0.177833</td>
#       <td id="T_787a2_row3_col1" class="data row3 col1" >-0.042834</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_787a2_row4_col0" class="data row4 col0" >-0.027500</td>
#       <td id="T_787a2_row4_col1" class="data row4 col1" >-0.019167</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_787a2_row5_col0" class="data row5 col0" >0.001667</td>
#       <td id="T_787a2_row5_col1" class="data row5 col1" >-0.000167</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_787a2_row6_col0" class="data row6 col0" >0.029166</td>
#       <td id="T_787a2_row6_col1" class="data row6 col1" >0.019666</td>
#     </tr>
#     <tr>
#       <th id="T_787a2_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_787a2_row7_col0" class="data row7 col0" >0.077000</td>
#       <td id="T_787a2_row7_col1" class="data row7 col1" >0.195000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# degrees latitude are approximately 110km
# longitude varies by latitude

min(df.SLAT.min(), df.ELAT.min()), max(df.SLAT.max(), df.ELAT.max())
# at ~45 degrees lat, 1 degree longitude is approx 80km
# Out:
# (39.971333, 47.85)

# %%
geo_columns = ['SLONG', 'ELONG', 'SLAT', 'ELAT']

df_geo = df[geo_columns].copy()
df_geo['LONG_DIFF'] = (df_geo['ELONG'] - df_geo['SLONG']) * 80 
df_geo['LAT_DIFF'] = (df_geo['ELAT'] - df_geo['SLAT']) * 110

df_geo[['LONG_DIFF', 'LAT_DIFF']].describe(percentiles=[0.01, 0.05, 0.1, .25, .5, .75, .9, .95, .99]).drop('count').style.format()
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc5d4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >LONG_DIFF</th>
#       <th class="col_heading level0 col1" >LAT_DIFF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc5d4_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_dc5d4_row0_col0" class="data row0 col0" >0.069482</td>
#       <td id="T_dc5d4_row0_col1" class="data row0 col1" >0.003159</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_dc5d4_row1_col0" class="data row1 col0" >2.297847</td>
#       <td id="T_dc5d4_row1_col1" class="data row1 col1" >2.209879</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_dc5d4_row2_col0" class="data row2 col0" >-14.226640</td>
#       <td id="T_dc5d4_row2_col1" class="data row2 col1" >-4.711740</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row3" class="row_heading level0 row3" >1%</th>
#       <td id="T_dc5d4_row3_col0" class="data row3 col0" >-3.320000</td>
#       <td id="T_dc5d4_row3_col1" class="data row3 col1" >-3.300000</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row4" class="row_heading level0 row4" >5%</th>
#       <td id="T_dc5d4_row4_col0" class="data row4 col0" >-3.160000</td>
#       <td id="T_dc5d4_row4_col1" class="data row4 col1" >-3.153260</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row5" class="row_heading level0 row5" >10%</th>
#       <td id="T_dc5d4_row5_col0" class="data row5 col0" >-3.000000</td>
#       <td id="T_dc5d4_row5_col1" class="data row5 col1" >-2.970000</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row6" class="row_heading level0 row6" >25%</th>
#       <td id="T_dc5d4_row6_col0" class="data row6 col0" >-2.200000</td>
#       <td id="T_dc5d4_row6_col1" class="data row6 col1" >-2.108370</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row7" class="row_heading level0 row7" >50%</th>
#       <td id="T_dc5d4_row7_col0" class="data row7 col0" >0.133360</td>
#       <td id="T_dc5d4_row7_col1" class="data row7 col1" >-0.018370</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row8" class="row_heading level0 row8" >75%</th>
#       <td id="T_dc5d4_row8_col0" class="data row8 col0" >2.333280</td>
#       <td id="T_dc5d4_row8_col1" class="data row8 col1" >2.163260</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row9" class="row_heading level0 row9" >90%</th>
#       <td id="T_dc5d4_row9_col0" class="data row9 col0" >3.026640</td>
#       <td id="T_dc5d4_row9_col1" class="data row9 col1" >2.988370</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row10" class="row_heading level0 row10" >95%</th>
#       <td id="T_dc5d4_row10_col0" class="data row10 col0" >3.173360</td>
#       <td id="T_dc5d4_row10_col1" class="data row10 col1" >3.153260</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row11" class="row_heading level0 row11" >99%</th>
#       <td id="T_dc5d4_row11_col0" class="data row11 col0" >3.346720</td>
#       <td id="T_dc5d4_row11_col1" class="data row11 col1" >3.300000</td>
#     </tr>
#     <tr>
#       <th id="T_dc5d4_level0_row12" class="row_heading level0 row12" >max</th>
#       <td id="T_dc5d4_row12_col0" class="data row12 col0" >6.160000</td>
#       <td id="T_dc5d4_row12_col1" class="data row12 col1" >21.450000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 95th Percentile is approx 3 km
df_geo[['LONG_DIFF', 'LAT_DIFF']].describe(percentiles=[0.025, .975]).drop(['count', 'mean', 'std', '50%', 'min', 'max']).style.format()
# Out:
# <style type="text/css">
# </style>
# <table id="T_3691f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >LONG_DIFF</th>
#       <th class="col_heading level0 col1" >LAT_DIFF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3691f_level0_row0" class="row_heading level0 row0" >2.5%</th>
#       <td id="T_3691f_row0_col0" class="data row0 col0" >-3.240000</td>
#       <td id="T_3691f_row0_col1" class="data row0 col1" >-3.226630</td>
#     </tr>
#     <tr>
#       <th id="T_3691f_level0_row1" class="row_heading level0 row1" >97.5%</th>
#       <td id="T_3691f_row1_col0" class="data row1 col0" >3.253360</td>
#       <td id="T_3691f_row1_col1" class="data row1 col1" >3.226630</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4km hypotenuse 
(3*3 + 3*3)**0.5
# Out:
# 4.242640687119285

# %%
# max 7.4 km total distance
# converted from nautical miles to km
pd.DataFrame((df.DIST*1.852).describe(percentiles=[0.01, 0.05, 0.1, .25, .5, .75, .9, .95, .99])).drop('count').style.format()
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc61c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DIST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc61c_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_cc61c_row0_col0" class="data row0 col0" >3.226031</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_cc61c_row1_col0" class="data row1 col0" >0.379222</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_cc61c_row2_col0" class="data row2 col0" >1.092680</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row3" class="row_heading level0 row3" >1%</th>
#       <td id="T_cc61c_row3_col0" class="data row3 col0" >2.111280</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row4" class="row_heading level0 row4" >5%</th>
#       <td id="T_cc61c_row4_col0" class="data row4 col0" >2.592800</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row5" class="row_heading level0 row5" >10%</th>
#       <td id="T_cc61c_row5_col0" class="data row5 col0" >2.963200</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row6" class="row_heading level0 row6" >25%</th>
#       <td id="T_cc61c_row6_col0" class="data row6 col0" >3.148400</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row7" class="row_heading level0 row7" >50%</th>
#       <td id="T_cc61c_row7_col0" class="data row7 col0" >3.241000</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row8" class="row_heading level0 row8" >75%</th>
#       <td id="T_cc61c_row8_col0" class="data row8 col0" >3.333600</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row9" class="row_heading level0 row9" >90%</th>
#       <td id="T_cc61c_row9_col0" class="data row9 col0" >3.444720</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row10" class="row_heading level0 row10" >95%</th>
#       <td id="T_cc61c_row10_col0" class="data row10 col0" >3.704000</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row11" class="row_heading level0 row11" >99%</th>
#       <td id="T_cc61c_row11_col0" class="data row11 col0" >4.592960</td>
#     </tr>
#     <tr>
#       <th id="T_cc61c_level0_row12" class="row_heading level0 row12" >max</th>
#       <td id="T_cc61c_row12_col0" class="data row12 col0" >7.408000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# may be easier to average start and end lat/long
# may be a way to interpolate from start to end of tow

df[(df.SPEC==10)&(df.MISSION=='NED2010001')&(df.SETNO==3)&(df.DATETIME.dt.year==2010)]
# Out:
#                    DATETIME  SEASON     MISSION  SETNO  TOTWGT  TOTNO  SPEC  \
# 1431366 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431367 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431384 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431387 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431390 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431410 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431411 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431412 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431429 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
# 1431490 2010-02-27 02:38:00  SPRING  NED2010001      3      28     10    10
#
#            COMMON_NAME SCIENTIFIC_NAME  FLEN   FWT       MATURITY     SEX  \
# 1431366  COD(ATLANTIC)    GADUS MORHUA    82 4_290  Ripe (Mature)  FEMALE
# 1431367  COD(ATLANTIC)    GADUS MORHUA    77 3_585          Spent  FEMALE
# 1431384  COD(ATLANTIC)    GADUS MORHUA    71 3_352          Spent    MALE
# 1431387  COD(ATLANTIC)    GADUS MORHUA   101 8_570          Spent  FEMALE
# 1431390  COD(ATLANTIC)    GADUS MORHUA    44   696       Immature  FEMALE
# 1431410  COD(ATLANTIC)    GADUS MORHUA    49 1_072        Resting  FEMALE
# 1431411  COD(ATLANTIC)    GADUS MORHUA    52 1_226        Resting  FEMALE
# 1431412  COD(ATLANTIC)    GADUS MORHUA    53   NaN     Recovering    MALE
# 1431429  COD(ATLANTIC)    GADUS MORHUA    40   538       Immature    MALE
# 1431490  COD(ATLANTIC)    GADUS MORHUA    72 3_294          Spent    MALE
#
#          AGE  SPECIMEN_ID STRAT  SLAT  SLONG  ELAT  ELONG  DUR  DIST  SPEED  \
# 1431366    7         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431367    5         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431384    4         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431387   10         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431390    2         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431410    3         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431411    4         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431412    5         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431429    3         <NA>   5Z2    42    -66    42    -66   30     2      3
# 1431490    7         <NA>   5Z2    42    -66    42    -66   30     2      3
#
#          DEPTH  SURF_TEMP  BOTT_TEMP  BOTT_SAL           GEARDESC VESEL  \
# 1431366     80          5          6        33  Western IIA trawl     N
# 1431367     80          5          6        33  Western IIA trawl     N
# 1431384     80          5          6        33  Western IIA trawl     N
# 1431387     80          5          6        33  Western IIA trawl     N
# 1431390     80          5          6        33  Western IIA trawl     N
# 1431410     80          5          6        33  Western IIA trawl     N
# 1431411     80          5          6        33  Western IIA trawl     N
# 1431412     80          5          6        33  Western IIA trawl     N
# 1431429     80          5          6        33  Western IIA trawl     N
# 1431490     80          5          6        33  Western IIA trawl     N
#
#          CRUNO  YEAR
# 1431366      1  2010
# 1431367      1  2010
# 1431384      1  2010
# 1431387      1  2010
# 1431390      1  2010
# 1431410      1  2010
# 1431411      1  2010
# 1431412      1  2010
# 1431429      1  2010
# 1431490      1  2010

# %%
# the vast majority of tows are the same distance - approx 3km
pd.DataFrame(df.DIST*1.852).plot(kind='hist', bins=20, figsize=(24,8), legend=False, title='Histogram: Tow Distance in km');
plt.xlabel('Kilometers');

# %% [markdown]
#     Is 3km too much?
#         averaged values will be off by 0 to 1.5km on average (just under 1 km on average)
#         is this OK?
#
#     There is no way to accurately interpolate the exact value (no exact timestamps for specimens)
#         interpolating is not feasible
#
#     The other option is plotting a line from start to end, along which the species was obtained
#         This is likely to make for a more confusing and difficult visualisation
#         however, this may be a better option

# %%
# there are almost 10_000 distinct points where Cod were found
# could be difficult to display 10k lines, points are probably a better proxy
# could also scale the point by how many were found there
df[(df.SPEC == 10)][['SLAT', 'SLONG']].drop_duplicates()
# Out:
#          SLAT  SLONG
# 0          45    -67
# 108        45    -65
# 110        45    -65
# 255        45    -66
# 369        45    -66
# ...       ...    ...
# 2343171    44    -57
# 2343295    44    -58
# 2344074    44    -58
# 2346340    45    -60
# 2346597    45    -61
#
# [9864 rows x 2 columns]

# %% [markdown]
# ### mapping functions

# %%
# potential columns that may be useful for mapping function

mapping_columns = ['DATETIME', 'MISSION',  # MISSION data
                   'SETNO', 'TOTWGT', 'TOTNO',  # SETNO specific info
                   'SPEC', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 'SPECIMEN_ID',  # SPEC info, can lookup COMMON_NAME and SCIENTIFIC_NAME
                   'SLAT', 'SLONG', 'ELAT', 'ELONG',  # lat/long: may be best to average these for mapping
                   'STRAT', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL']  # tow info

# %%
# helper functions

def average_geo(dataframe):
    """
    averages SLAT and ELAT & SLONG and ELONG
    null values do not get averaged
    """
    geo_df = dataframe
    geo_df['LAT'] = geo_df[['SLAT', 'ELAT']].mean(axis=1)
    geo_df['LONG'] = geo_df[['SLONG', 'ELONG']].mean(axis=1)
    return geo_df.drop(['SLAT', 'ELAT', 'SLONG', 'ELONG'], axis=1)

temp = average_geo(df)
temp.tail().style.format({})
# temp.LONG.isna().sum()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab454_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DATETIME</th>
#       <th class="col_heading level0 col1" >SEASON</th>
#       <th class="col_heading level0 col2" >MISSION</th>
#       <th class="col_heading level0 col3" >SETNO</th>
#       <th class="col_heading level0 col4" >TOTWGT</th>
#       <th class="col_heading level0 col5" >TOTNO</th>
#       <th class="col_heading level0 col6" >SPEC</th>
#       <th class="col_heading level0 col7" >COMMON_NAME</th>
#       <th class="col_heading level0 col8" >SCIENTIFIC_NAME</th>
#       <th class="col_heading level0 col9" >FLEN</th>
#       <th class="col_heading level0 col10" >FWT</th>
#       <th class="col_heading level0 col11" >MATURITY</th>
#       <th class="col_heading level0 col12" >SEX</th>
#       <th class="col_heading level0 col13" >AGE</th>
#       <th class="col_heading level0 col14" >SPECIMEN_ID</th>
#       <th class="col_heading level0 col15" >STRAT</th>
#       <th class="col_heading level0 col16" >DUR</th>
#       <th class="col_heading level0 col17" >DIST</th>
#       <th class="col_heading level0 col18" >SPEED</th>
#       <th class="col_heading level0 col19" >DEPTH</th>
#       <th class="col_heading level0 col20" >SURF_TEMP</th>
#       <th class="col_heading level0 col21" >BOTT_TEMP</th>
#       <th class="col_heading level0 col22" >BOTT_SAL</th>
#       <th class="col_heading level0 col23" >GEARDESC</th>
#       <th class="col_heading level0 col24" >VESEL</th>
#       <th class="col_heading level0 col25" >CRUNO</th>
#       <th class="col_heading level0 col26" >YEAR</th>
#       <th class="col_heading level0 col27" >LAT</th>
#       <th class="col_heading level0 col28" >LONG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab454_level0_row0" class="row_heading level0 row0" >2346734</th>
#       <td id="T_ab454_row0_col0" class="data row0 col0" >2020-08-07 10:52:00</td>
#       <td id="T_ab454_row0_col1" class="data row0 col1" >SUMMER</td>
#       <td id="T_ab454_row0_col2" class="data row0 col2" >NED2020025</td>
#       <td id="T_ab454_row0_col3" class="data row0 col3" >206</td>
#       <td id="T_ab454_row0_col4" class="data row0 col4" >14.210000</td>
#       <td id="T_ab454_row0_col5" class="data row0 col5" >99</td>
#       <td id="T_ab454_row0_col6" class="data row0 col6" >4511</td>
#       <td id="T_ab454_row0_col7" class="data row0 col7" >SHORT-FIN SQUID</td>
#       <td id="T_ab454_row0_col8" class="data row0 col8" >ILLEX ILLECEBROSUS</td>
#       <td id="T_ab454_row0_col9" class="data row0 col9" >19.000000</td>
#       <td id="T_ab454_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_ab454_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_ab454_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_ab454_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_ab454_row0_col14" class="data row0 col14" >55571</td>
#       <td id="T_ab454_row0_col15" class="data row0 col15" >459</td>
#       <td id="T_ab454_row0_col16" class="data row0 col16" >30</td>
#       <td id="T_ab454_row0_col17" class="data row0 col17" >1.770000</td>
#       <td id="T_ab454_row0_col18" class="data row0 col18" >3.540000</td>
#       <td id="T_ab454_row0_col19" class="data row0 col19" >96.930000</td>
#       <td id="T_ab454_row0_col20" class="data row0 col20" >nan</td>
#       <td id="T_ab454_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_ab454_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_ab454_row0_col23" class="data row0 col23" >Western IIA trawl</td>
#       <td id="T_ab454_row0_col24" class="data row0 col24" >N</td>
#       <td id="T_ab454_row0_col25" class="data row0 col25" >25</td>
#       <td id="T_ab454_row0_col26" class="data row0 col26" >2020</td>
#       <td id="T_ab454_row0_col27" class="data row0 col27" >44.520167</td>
#       <td id="T_ab454_row0_col28" class="data row0 col28" >-61.075000</td>
#     </tr>
#     <tr>
#       <th id="T_ab454_level0_row1" class="row_heading level0 row1" >2346735</th>
#       <td id="T_ab454_row1_col0" class="data row1 col0" >2020-08-07 10:52:00</td>
#       <td id="T_ab454_row1_col1" class="data row1 col1" >SUMMER</td>
#       <td id="T_ab454_row1_col2" class="data row1 col2" >NED2020025</td>
#       <td id="T_ab454_row1_col3" class="data row1 col3" >206</td>
#       <td id="T_ab454_row1_col4" class="data row1 col4" >14.210000</td>
#       <td id="T_ab454_row1_col5" class="data row1 col5" >99</td>
#       <td id="T_ab454_row1_col6" class="data row1 col6" >4511</td>
#       <td id="T_ab454_row1_col7" class="data row1 col7" >SHORT-FIN SQUID</td>
#       <td id="T_ab454_row1_col8" class="data row1 col8" >ILLEX ILLECEBROSUS</td>
#       <td id="T_ab454_row1_col9" class="data row1 col9" >19.000000</td>
#       <td id="T_ab454_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_ab454_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_ab454_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_ab454_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_ab454_row1_col14" class="data row1 col14" >55542</td>
#       <td id="T_ab454_row1_col15" class="data row1 col15" >459</td>
#       <td id="T_ab454_row1_col16" class="data row1 col16" >30</td>
#       <td id="T_ab454_row1_col17" class="data row1 col17" >1.770000</td>
#       <td id="T_ab454_row1_col18" class="data row1 col18" >3.540000</td>
#       <td id="T_ab454_row1_col19" class="data row1 col19" >96.930000</td>
#       <td id="T_ab454_row1_col20" class="data row1 col20" >nan</td>
#       <td id="T_ab454_row1_col21" class="data row1 col21" >nan</td>
#       <td id="T_ab454_row1_col22" class="data row1 col22" >nan</td>
#       <td id="T_ab454_row1_col23" class="data row1 col23" >Western IIA trawl</td>
#       <td id="T_ab454_row1_col24" class="data row1 col24" >N</td>
#       <td id="T_ab454_row1_col25" class="data row1 col25" >25</td>
#       <td id="T_ab454_row1_col26" class="data row1 col26" >2020</td>
#       <td id="T_ab454_row1_col27" class="data row1 col27" >44.520167</td>
#       <td id="T_ab454_row1_col28" class="data row1 col28" >-61.075000</td>
#     </tr>
#     <tr>
#       <th id="T_ab454_level0_row2" class="row_heading level0 row2" >2346736</th>
#       <td id="T_ab454_row2_col0" class="data row2 col0" >2020-08-07 10:52:00</td>
#       <td id="T_ab454_row2_col1" class="data row2 col1" >SUMMER</td>
#       <td id="T_ab454_row2_col2" class="data row2 col2" >NED2020025</td>
#       <td id="T_ab454_row2_col3" class="data row2 col3" >206</td>
#       <td id="T_ab454_row2_col4" class="data row2 col4" >14.210000</td>
#       <td id="T_ab454_row2_col5" class="data row2 col5" >99</td>
#       <td id="T_ab454_row2_col6" class="data row2 col6" >4511</td>
#       <td id="T_ab454_row2_col7" class="data row2 col7" >SHORT-FIN SQUID</td>
#       <td id="T_ab454_row2_col8" class="data row2 col8" >ILLEX ILLECEBROSUS</td>
#       <td id="T_ab454_row2_col9" class="data row2 col9" >19.000000</td>
#       <td id="T_ab454_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_ab454_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_ab454_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_ab454_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_ab454_row2_col14" class="data row2 col14" >55594</td>
#       <td id="T_ab454_row2_col15" class="data row2 col15" >459</td>
#       <td id="T_ab454_row2_col16" class="data row2 col16" >30</td>
#       <td id="T_ab454_row2_col17" class="data row2 col17" >1.770000</td>
#       <td id="T_ab454_row2_col18" class="data row2 col18" >3.540000</td>
#       <td id="T_ab454_row2_col19" class="data row2 col19" >96.930000</td>
#       <td id="T_ab454_row2_col20" class="data row2 col20" >nan</td>
#       <td id="T_ab454_row2_col21" class="data row2 col21" >nan</td>
#       <td id="T_ab454_row2_col22" class="data row2 col22" >nan</td>
#       <td id="T_ab454_row2_col23" class="data row2 col23" >Western IIA trawl</td>
#       <td id="T_ab454_row2_col24" class="data row2 col24" >N</td>
#       <td id="T_ab454_row2_col25" class="data row2 co

# %%
# helper function

def filter_dates(dataframe, date_min=None, date_max=None):
    """
    date_min and date_max are strings, formatted to be interpreted by pandas to_datetime() function
    """
    # initialise dates
    datetime_min, datetime_max = dataframe.DATETIME.min(), dataframe.DATETIME.max()
    
    # if dates are inputted, create filters for dataframe
    if date_min:
        datetime_min = pd.to_datetime(date_min)
    if date_max:
        datetime_max = pd.to_datetime(date_max)
        
    # filter dataframe by dates
    return dataframe[(dataframe.DATETIME >= datetime_min) & (dataframe.DATETIME <= datetime_max)]

# testing
temp = filter_dates(df, '1980', '2001-9-11')
display(temp.head())
display(temp.tail())
# Out:
#                   DATETIME  SEASON     MISSION  SETNO  TOTWGT  TOTNO  SPEC  \
# 212557 1980-03-05 09:15:00  SPRING  HAM1980033      1       3     34    40
# 212558 1980-03-05 09:15:00  SPRING  HAM1980033      1       3     34    40
# 212559 1980-03-05 09:15:00  SPRING  HAM1980033      1       3     34    40
# 212560 1980-03-05 09:15:00  SPRING  HAM1980033      1       3     34    40
# 212561 1980-03-05 09:15:00  SPRING  HAM1980033      1       3     34    40
#
#             COMMON_NAME               SCIENTIFIC_NAME  FLEN  FWT  \
# 212557  AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    21   50
# 212558  AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    20  NaN
# 212559  AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    20   75
# 212560  AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    22   75
# 212561  AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    19   50
#
#              MATURITY     SEX  AGE  SPECIMEN_ID STRAT  SLAT  SLONG  ELAT  \
# 212557  Ripe (Mature)    MALE    4         <NA>   459    45    -61   NaN
# 212558            NaN  FEMALE  NaN         <NA>   459    45    -61   NaN
# 212559       Immature  FEMALE    3         <NA>   459    45    -61   NaN
# 212560       Immature    MALE    5         <NA>   459    45    -61   NaN
# 212561       Immature  FEMALE    3         <NA>   459    45    -61   NaN
#
#         ELONG  DUR  DIST  SPEED  DEPTH  SURF_TEMP  BOTT_TEMP  BOTT_SAL  \
# 212557    NaN   30     3      5    155          1          2        32
# 212558    NaN   30     3      5    155          1          2        32
# 212559    NaN   30     3      5    155          1          2        32
# 212560    NaN   30     3      5    155          1          2        32
# 212561    NaN   30     3      5    155          1          2        32
#
#                  GEARDESC VESEL  CRUNO  YEAR  LAT  LONG
# 212557  Western IIA trawl     H     33  1980   45   -61
# 212558  Western IIA trawl     H     33  1980   45   -61
# 212559  Western IIA trawl     H     33  1980   45   -61
# 212560  Western IIA trawl     H     33  1980   45   -61
# 212561  Western IIA trawl     H     33  1980   45   -61
#                    DATETIME  SEASON     MISSION  SETNO  TOTWGT  TOTNO  SPEC  \
# 1088506 2001-07-30 22:48:00  SUMMER  NED2001037    109       8     38    60
# 1088507 2001-07-30 22:48:00  SUMMER  NED2001037    109       8     38    60
# 1088508 2001-07-30 22:48:00  SUMMER  NED2001037    109       8     38    60
# 1088509 2001-07-30 22:48:00  SUMMER  NED2001037    109       8     38    60
# 1088510 2001-07-30 22:48:00  SUMMER  NED2001037    109       1     12    40
#
#                COMMON_NAME               SCIENTIFIC_NAME  FLEN  FWT MATURITY  \
# 1088506  HERRING(ATLANTIC)               CLUPEA HARENGUS    27  NaN      NaN
# 1088507  HERRING(ATLANTIC)               CLUPEA HARENGUS    28  270      NaN
# 1088508  HERRING(ATLANTIC)               CLUPEA HARENGUS    28  NaN      NaN
# 1088509  HERRING(ATLANTIC)               CLUPEA HARENGUS    29  NaN      NaN
# 1088510    AMERICAN PLAICE  HIPPOGLOSSOIDES PLATESSOIDES    22   74      NaN
#
#           SEX  AGE  SPECIMEN_ID STRAT  SLAT  SLONG  ELAT  ELONG  DUR  DIST  \
# 1088506   NaN  NaN         <NA>   462    44    -62    44    -61   30     2
# 1088507   NaN  NaN         <NA>   462    44    -62    44    -61   30     2
# 1088508   NaN  NaN         <NA>   462    44    -62    44    -61   30     2
# 1088509   NaN  NaN         <NA>   462    44    -62    44    -61   30     2
# 1088510  MALE  NaN         <NA>   462    44    -62    44    -61   30     2
#
#          SPEED  DEPTH  SURF_TEMP  BOTT_TEMP  BOTT_SAL           GEARDESC  \
# 1088506      4    146         18          6        34  Western IIA trawl
# 1088507      4    146         18          6        34  Western IIA trawl
# 1088508      4    146         18          6        34  Western IIA trawl
# 1088509      4    146         18          6        34  Western IIA trawl
# 1088510      4    146         18          6        34  Western IIA trawl
#
#         VESEL  CRUNO  YEAR  LAT  LONG
# 1088506     N     37  2001   44   -62
# 1088507     N     37  2001   44   -62
# 1088508     N     37  2001   44   -62
# 1088509     N     37  2001   44   -62
# 1088510     N     37  2001   44   -62

# %% [markdown]
# ## mapping and visualisation functions

# %%
def scatterplot_species(dataframe, species_code, x='DATETIME', y='DEPTH', date_min=None, date_max=None):
    """scatterplot of 2 species attributes: defaults to plotting depth vs time"""
    plot_df = filter_dates(dataframe[dataframe.SPEC==species_code], date_min, date_max)
    if y == 'DEPTH':
        # NOTE: colour is hard-coded because jupyter was giving errors. this is just the default colour.
        plot_df.plot(x=x, y=y, kind='scatter', figsize=(30, 12), c='#4C72B0', title=f'{get_species(species_code)}: {y} as a function of {x}').invert_yaxis()
    else:
        plot_df.plot(x=x, y=y, kind='scatter', figsize=(30, 12), c='#4C72B0', title=f'{get_species(species_code)}: {y} as a function of {x}')

# %%
scatterplot_species(df, 10, y='FWT')

# %%
scatterplot_species(df, 10, x='DEPTH', y='FWT')

# %%
scatterplot_species(df, 10, date_min='1980', date_max='2001')

# %%
scatterplot_species(df, 602)

# %% [markdown]
# # MAPPING FUNCTIONS

# %%
def species_code_to_list(species_code, min_species=None):
    """
    species_code='all' returns all species, otherwise, 
    species_code can be an in or a list of ints
    returns name(s) of species and code(s) in list format
    """
    
    # THIS MAY BE TOO MUCH DATA, TEST THIS
    if species_code == 'all':
        # drop fish without greater count
        if min_species != None:
            spec_counts = pd.DataFrame(df.SPEC.value_counts())
            return list(spec_counts[spec_counts.SPEC > min_species].index), f'All Species With More Than {min_species} Species'
        # if min_species isn't inputted, actually output all species
        return list(SPECIES.SPEC), 'All Species'
    
    if isinstance(species_code, list):
        species_name = ''
        for i in species_code:
            species_name = species_name + ' / ' + get_species(i)
        species_name = species_name[3:]
    else:
        species_name = get_species(species_code)
        species_code = [species_code]
            
    return species_code, species_name

len(species_code_to_list('all', min_species=100000)[0])
# Out:
# 7

# %%
def geo_species(dataframe, species_code, date_min=None, date_max=None, min_species=None):
    """
    species_code can be an in or a list of ints
    date_min and date_max are strings, formatted to be interpreted by pandas to_datetime() function
    """
    # columns to be used in visualisation
    species_mapping_columns = ['DATETIME', 'SPEC', 'COMMON_NAME', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 
        'SLAT', 'SLONG', 'ELAT', 'ELONG',  # these are averaged to get LAT, LONG
        'SETNO', 'TOTNO',  # maybe just for debugging
        'STRAT', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL']  # tow info
    
    # just need the species code(s)
    species_code = species_code_to_list(species_code, min_species=min_species)[0]
    
    # create dataframe with full dates
    map_df = dataframe[species_mapping_columns][dataframe['SPEC'].isin(species_code)]
    map_df = filter_dates(map_df, date_min, date_max)
    map_df = average_geo(map_df)
    
        
    # change SPEC to string so that it graphs as a discrete categorical variable
    map_df['SPEC'] = map_df['SPEC'].astype(str)

    return map_df

# %%
# %%time
temp = geo_species(df, 'all')
temp.sample(10)
# Out:
# Wall time: 2.17 s
#                    DATETIME  SPEC           COMMON_NAME  FLEN   FWT  \
# 925553  1998-07-13 16:24:00  4511       SHORT-FIN SQUID    13    40
# 298224  1981-10-15 01:15:00    11               HADDOCK    32   350
# 1799180 2015-08-04 20:58:00    13  SQUIRREL OR RED HAKE    27   123
# 1039094 2000-07-22 20:59:00   610   NORTHERN SAND LANCE    13     8
# 176784  1979-03-26 04:05:00   204          WINTER SKATE    54 1_000
# 1563311 2012-07-14 03:59:00   320             SEA RAVEN    30   NaN
# 654133  1990-07-20 07:45:00    23   REDFISH UNSEPARATED    25   250
# 156133  1978-11-17 00:55:00    16               POLLOCK    69 3_300
# 1448127 2010-03-28 00:39:00    11               HADDOCK    47 1_020
# 553092  1987-07-17 17:35:00    12            WHITE HAKE    49   NaN
#
#                    MATURITY      SEX  AGE STRAT  DUR  DIST  SPEED  DEPTH  \
# 925553                  NaN      NaN  NaN   484   30     2      4    189
# 298224             Immature   FEMALE    2   463   30     2      4     79
# 1799180                 NaN      NaN  NaN   460   30     2      4    151
# 1039094                 NaN      NaN  NaN   445   25     2      4    155
# 176784                  NaN   FEMALE  NaN   455   30     2      3     35
# 1563311                 NaN      NaN  NaN   494   30     2      4     56
# 654133                  NaN     MALE  NaN   440   30     2      3    331
# 156133           Ripening 1   FEMALE  NaN   462   30     2      4    128
# 1448127  Spawning (Running)   FEMALE    7   410   30     2      4    108
# 553092                  NaN  UNKNOWN  NaN   440   30     2      3    207
#
#          SURF_TEMP  BOTT_TEMP  BOTT_SAL  LAT  LONG
# 925553          11          6        34   44   -67
# 298224          13          8        34   43   -62
# 1799180         18         10        35   44   -63
# 1039094         17          3        33   45   -58
# 176784           1          1        32   44   -61
# 1563311         13         12        32   45   -65
# 654133          16          6        35   46   -59
# 156133          10          6       NaN   44   -62
# 1448127        NaN        NaN       NaN   43   -63
# 553092          17          1        34   47   -60

# %%
def aggregate_by_geo(dataframe, species_code, min_species=None, verbose=False):
    ##TODO: confirm and reduce entries for DEPTH

    aggregation = {
        'DEPTH': ['count', 'min', 'max', 'mean'],  # count is how many fish in that location
        'FWT': ['sum', 'min', 'max', 'mean'],  # cum is total weight of fish in that location
        'AGE': ['min', 'max', 'mean'], 
        'FLEN': ['min', 'max', 'mean']
    }

    if verbose:
        aggregation.update({
            'DATETIME': ['mean'], 
            'SPEED': ['mean'], 
            'DIST': ['mean'], 
            'DUR': ['mean'], 
            'SURF_TEMP': ['mean'], 
            'BOTT_TEMP': ['mean'], 
            'BOTT_SAL': ['mean']
        })

    gdf = geo_species(dataframe, species_code, min_species=min_species).drop(['MATURITY', 'SEX', 'STRAT'], axis=1)
    
    return gdf.groupby(['SPEC', 'COMMON_NAME', 'LAT', 'LONG']).agg(aggregation)

# %%
# how to flatten dataframe
# almost: need to rename columns
# aggregate_by_geo(df, 'all', min_species=1000, verbose=True).droplevel(axis=1, level=1).reset_index()
aggregate_by_geo(df, 'all', min_species=1000, verbose=True).droplevel(axis=1, level=1).reset_index().columns
# Out:
# Index(['SPEC', 'COMMON_NAME', 'LAT', 'LONG', 'DEPTH', 'DEPTH', 'DEPTH',
#        'DEPTH', 'FWT', 'FWT', 'FWT', 'FWT', 'AGE', 'AGE', 'AGE', 'FLEN',
#        'FLEN', 'FLEN', 'DATETIME', 'SPEED', 'DIST', 'DUR', 'SURF_TEMP',
#        'BOTT_TEMP', 'BOTT_SAL'],
#       dtype='object')

# %%
search_species_by_name('cod')
# Out:
#        SPEC       COMMON_NAME    SCIENTIFIC_NAME
# index
# 10       10     COD(ATLANTIC)       GADUS MORHUA
# 17       17  TOMCOD(ATLANTIC)  MICROGADUS TOMCOD
# 110     110        ARCTIC COD   BOREOGADUS SAIDA
# 118     118     GREENLAND COD         GADUS OGAC

# %%
def map_species(dataframe, species_code, color='DEPTH', hover_data=None, min_species=None, verbose=False, aggregate_data=True):
    """
    TODO: UPDATE WITH AGGREGATE GDF
    """
    
    # just need the species names(s)
    species_name = species_code_to_list(species_code)[1]
    
    # filter the full dataframe for mapping = gdf
    if aggregate_data:
        # aggregate by lat/long, species, and filter entries with less than min_species
        gdf = aggregate_by_geo(dataframe, species_code, min_species=min_species, verbose=verbose)
        gdf.columns = ['_'.join(col) for col in gdf.columns.values]  # flatten the dataframe
        gdf.reset_index(inplace=True)
        gdf.rename(columns={'DEPTH_count': 'COUNT', 'FWT_sum': 'TOTAL_weight'}, inplace=True)
    else:
        gdf = geo_species(dataframe, species_code, min_species=min_species)
        
    # custom hover data if inputted
    if hover_data == None:
        hover_data=gdf.columns
    else:
        hover_data=hover_data
    
    # make the plot
    fig = px.scatter_geo(gdf, lat='LAT', lon='LONG', 
        hover_data=hover_data, color=color,
        projection='natural earth', scope='north america', 
        title=f'Map of {species_name} Coloured by {color}'
    )
    fig.update_geos(resolution=50, projection_scale=10, center=dict(lat=44, lon=-63))
    fig.update_layout(width=1200, height=800, title_x=0.5)
    
    # show the plot
    fig.show()
#     return gdf

# %%
# %%time
# still slow, even when aggregated and filtered to 100k+ species (7 species, but many datapoints)
# map_species(df, 'all', color='COMMON_NAME', min_species=100_000, aggregate_data=True)
# Out:
# Wall time: 0 ns

# %%
# filter by species not working
aggregate_by_geo(df, 'all', min_species=100_000)
# Out:
#                                 DEPTH                FWT                    \
#                                 count min max mean   sum   min   max  mean
# SPEC COMMON_NAME       LAT LONG
# 10   COD(ATLANTIC)     40  -69      1  83  83   83 1_210 1_210 1_210 1_210
#                            -69      1  88  88   88 4_400 4_400 4_400 4_400
#                            -69      4  84  84   84   912   156   262   228
#                            -69      5  89  89   89 7_804   494 3_674 1_561
#                            -69      2  65  65   65   622   302   320   311
# ...                               ...  ..  ..  ...   ...   ...   ...   ...
# 60   HERRING(ATLANTIC) 47  -60      3 218 218  218   694   120   324   231
#                            -60      1 155 155  155   260   260   260   260
#                            -60      4 277 277  277   728   120   256   182
#                            -60      1 236 236  236   275   275   275   275
#                            -60     10 173 173  173 2_066   112   270   207
#
#                                 AGE          FLEN
#                                 min max mean  min max mean
# SPEC COMMON_NAME       LAT LONG
# 10   COD(ATLANTIC)     40  -69    3   3    3   48  48   48
#                            -69    4   4    4   74  74   74
#                            -69    2   2    2   27  32   30
#                            -69    2   4    3   38  66   51
#                            -69    2   2    2   33  34   34
# ...                              ..  ..  ...  ...  ..  ...
# 60   HERRING(ATLANTIC) 47  -60  NaN NaN  NaN   23  31   27
#                            -60  NaN NaN  NaN   28  28   28
#                            -60  NaN NaN  NaN  255 298  279
#                            -60  NaN NaN  NaN   31  31   31
#                            -60  NaN NaN  NaN   21  29   26
#
# [56644 rows x 14 columns]

# %%
# %%time
# test the map with all cod
# map_species(df, [10, 17, 110, 118], color='COMMON_NAME', aggregate_data=True)
# Out:
# Wall time: 0 ns

# %%
## TODO 
# check how many times same location but different tow number/date

species_code = 'all'
verbose = True
min_species = False

aggregation = {
    'DEPTH': ['count', 'min', 'max', 'mean'],  # count is how many fish in that location
    'FWT': ['sum', 'min', 'max', 'mean'],  # cum is total weight of fish in that location
    'AGE': ['min', 'max', 'mean'], 
    'FLEN': ['min', 'max', 'mean']
}

# maybe just debugging
aggregation.update({
        'SETNO': ['mean'], 
        'TOTNO': ['mean']
    })

if verbose:
    aggregation.update({
        'DATETIME': ['mean'], 
        'SPEED': ['mean'], 
        'DIST': ['mean'], 
        'DUR': ['mean'], 
        'SURF_TEMP': ['mean'], 
        'BOTT_TEMP': ['mean'], 
        'BOTT_SAL': ['mean']
    })

gdf = geo_species(df, species_code, min_species=min_species).drop(['MATURITY', 'SEX', 'STRAT'], axis=1)

gdf.groupby(['SPEC', 'COMMON_NAME', 'LAT', 'LONG']).agg(aggregation)
# Out:
#                             DEPTH                FWT                   AGE  \
#                             count min max mean   sum   min   max  mean min
# SPEC COMMON_NAME   LAT LONG
# 10   COD(ATLANTIC) 40  -69      1  83  83   83 1_210 1_210 1_210 1_210   3
#                        -69      1  88  88   88 4_400 4_400 4_400 4_400   4
#                        -69      4  84  84   84   912   156   262   228   2
#                        -69      5  89  89   89 7_804   494 3_674 1_561   2
#                        -69      2  65  65   65   622   302   320   311   2
# ...                           ...  ..  ..  ...   ...   ...   ...   ...  ..
# 9999 RESERVED      43  -65      1 124 124  124    10    10    10    10 NaN
#                        -63      1 114 114  114    38    38    38    38 NaN
#                        -62      1 319 319  319     4     4     4     4 NaN
#                        -61      1 605 605  605    50    50    50    50 NaN
#                    46  -59      1 123 123  123     0   NaN   NaN   NaN NaN
#
#                                      FLEN          SETNO TOTNO  \
#                             max mean  min max mean  mean  mean
# SPEC COMMON_NAME   LAT LONG
# 10   COD(ATLANTIC) 40  -69    3    3   48  48   48    81     1
#                        -69    4    4   74  74   74    81     1
#                        -69    2    2   27  32   30    65     4
#                        -69    4    3   38  66   51    81     5
#                        -69    2    2   33  34   34    67     2
# ...                          ..  ...  ...  ..  ...   ...   ...
# 9999 RESERVED      43  -65  NaN  NaN   13  13   13    26     1
#                        -63  NaN  NaN   20  20   20    83     1
#                        -62  NaN  NaN    8   8    8    87     1
#                        -61  NaN  NaN   42  42   42    90     1
#                    46  -59  NaN  NaN  NaN NaN  NaN   159     0
#
#                                        DATETIME SPEED DIST  DUR SURF_TEMP  \
#                                            mean  mean mean mean      mean
# SPEC COMMON_NAME   LAT LONG
# 10   COD(ATLANTIC) 40  -69  2003-02-25 15:53:00     3    2   30       NaN
#                        -69  1990-03-01 00:05:00     4    2   30         5
#                        -69  2005-02-26 18:21:00     4    2   30         4
#                        -69  2004-02-15 04:15:00     4    2   30       NaN
#                        -69  2005-02-27 23:54:00     4    2   30         4
# ...                                         ...   ...  ...  ...       ...
# 9999 RESERVED      43  -65  1995-06-28 12:08:00     4    2   30        10
#                        -63  1996-07-13 15:11:00     4    2   30        16
#                        -62  1995-07-05 15:07:00     4    2   30        17
#                        -61  1995-07-06 23:54:00     3    1   25        14
#                    46  -59  2007-07-28 10:21:00     4    2   30        19
#
#                             BOTT_TEMP BOTT_SAL
#                                  mean     mean
# SPEC COMMON_NAME   LAT LONG
# 10   COD(ATLANTIC) 40  -69        NaN      NaN
#                        -69          6       34
#                        -69          4       33
#                        -69        NaN      NaN
#                        -69          4       32
# ...                               ...      ...
# 9999 RESERVED      43  -65          5       33
#                        -63          9       35
#                        -62          6       35
#                        -61          5       35
#                    46  -59          2       33
#
# [230358 rows x 23 columns]

# %%
# how many times same location/species but different tow number/date

test = average_geo(df)
test = test.groupby(['SPEC', 'LAT', 'LONG'])
columns = ['DATETIME', 'SETNO', 'TOTNO', 'DEPTH']
test = test[columns].mean().reset_index()
print('\nnumber of duplicated rows:  ', test.duplicated().sum())
display(test.head())
# Out:
# number of duplicated rows:   0
#    SPEC  LAT  LONG  SETNO  TOTNO  DEPTH
# 0     3   42   -65     54      1     99
# 1     6   43   -61     11      1    119
# 2     6   44   -61     25      1     51
# 3     6   44   -60     19      1     31
# 4     6   45   -59     54      1     91

# %%
test = test.drop(['SETNO', 'TOTNO'], axis=1)
print('\nnumber of duplicated rows:  ', test.duplicated().sum())
display(test.head())
# Out:
# number of duplicated rows:   0
#    SPEC  LAT  LONG  DEPTH
# 0     3   42   -65     99
# 1     6   43   -61    119
# 2     6   44   -61     51
# 3     6   44   -60     31
# 4     6   45   -59     91

# %% [markdown]
# ## THEREFORE:  only aggregate DEPTH to max when aggregating (a few rounding issues with mean)

# %%
# %%time
# map_species(df, 'all', color='DEPTH_max', min_species=10000, aggregate_data=True)
# Out:
# Wall time: 0 ns

# %%
# aggregate_by_geo(df, 'all', verbose=True)

# %%
def density_species(dataframe, species_code, color='DEPTH', hover_data=None):
    """
    TODO: UPDATE WITH AGGREGATE GDF
    """
    
    # just need the species names(s)
    species_name = species_code_to_list(species_code)[1]
    
    # filter the full dataframe for mapping = gdf
    gdf = geo_species(dataframe, species_code)
    
    # custom hover data if inputted
    if hover_data == None:
        hover_data=gdf.columns
    else:
        hover_data=hover_data
    
    # make the plot
    fig = px.density_mapbox(
        gdf, lat='LAT', lon='LONG', 
        z=color, radius=10,
        center=dict(lat=44, lon=-63), zoom=5,
        hover_data=hover_data,
        mapbox_style="stamen-terrain"
    )

    fig.update_layout(
        width=900, height=700, 
        title_x=0.5, title=f'Map of {species_name} Coloured by {color}'
    )
    
    # show the plot
    fig.show()

# %%
# still very slow with cod or haddock
# formatting very wonky, depth seems to be cumulative (heatmap?)
density_species(df, 602)

# %% [markdown]
# ### Optional Functions

# %%
def map_missions(mission_code, date_range=None):
    pass


def query_by_location(lat, long, radius_in_km):
    pass
