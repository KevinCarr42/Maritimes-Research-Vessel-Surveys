# %% [markdown]
# # import modules

# %%
# imports
import pandas as pd
import numpy as np
import filecmp

# full-width display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # import and organise data

# %%
# file directories
path_4VSW = '4VSW_csv'
path_FALL = 'FALL_csv'
path_SPRING = 'SPRING_csv'
path_SUMMER = 'SUMMER_csv'

file_paths = [path_4VSW, path_FALL, path_SPRING, path_SUMMER]

# %%
# compare data dictionaries
dct_4vs = f'./{file_paths[0]}/DataDictionary_202008.xlsx'
dct_fal = f'./{file_paths[1]}/DataDictionary_202008.xlsx'
dct_spr = f'./{file_paths[2]}/DataDictionary_202008.xlsx'
dct_sum = f'./{file_paths[3]}/DataDictionary_202008.xlsx'

if filecmp.cmp(dct_4vs, dct_fal) and filecmp.cmp(dct_fal, dct_spr) and filecmp.cmp(dct_spr, dct_sum):
    print('All data dictionaries are the same.')
else:
    print('There are differences in the data dictionaries.')
# Out:
# All data dictionaries are the same.

# %%
# import data dictionary as dataframe
data_dictionary = pd.read_excel(dct_4vs)
data_dictionary.dropna(inplace=True)  # drop empty / NaN rows

# data_dictionary.drop('FRANÇAIS', axis=1)

# %%
# file names
GSCAT = '2020_GSCAT.csv'
GSDET = '2020_GSDET.csv'
GSINF = '2020_GSINF.csv'
GSSPECIES = '2020_GSSPECIES.csv'
GSMISSIONS = '2020GSMISSIONS.csv'

file_sfx = [GSCAT, GSDET, GSINF, GSSPECIES, GSMISSIONS]
file_names = ['GSCAT', 'GSDET', 'GSINF', 'GSSPECIES', 'GSMISSIONS']

# %%
# list of all files
all_files = []
for path in file_paths:
    for file in file_sfx:
        all_files.append(f"./{path}/{path[:-4]}_{file}")

# %% [markdown]
# # investigate and tidy data

# %% [markdown]
# ### helper functions for viewing data

# %%
# helper functions to print information about files
# these functions presuppose the naming scheme "file_names", "all_files"

def get_season(file_number):
    return all_files[file_number].split('/')[1][:-4]

def get_filename(file_number):
    return file_names[file_number % 5]

def print_information(file_number):
    print(get_filename(file_number), f'({get_season(file_number)})')
    print()
    print('columns:', list(pd.read_csv(all_files[file_number]).columns))
    print('shape:', pd.read_csv(all_files[file_number]).shape)
    print('\ninfo:\n')
    print(pd.read_csv(all_files[file_number]).info())
#     print('\ndescribe:\n')
#     print(pd.read_csv(all_files[file_number]).describe())
    print('\n\n')

# %% [markdown]
# ### helper function for combining seasons

# %%
def combine_seasons(list_of_files, dtype={}):
    """
    requires all_files naming structure defined above
    
    error handling:
        from GSDET (SPRING): 
            DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
                need to add a dtype kwarg to the combine_seasons() function
                could use **kwargs, but dtype={} seems less prone to error
    """
    
    # initialise empty dataframe
    df_output = pd.DataFrame()
    
    for file_number in list_of_files:
        dftemp = pd.read_csv(all_files[file_number], dtype=dtype)
        
        # add SEASON and FILE columns (temporarily) to keep track of data origins
        dftemp['SEASON'] = all_files[file_number].split('/')[1][:-4]
        dftemp['FILE'] = file_names[file_number % 5]
        
        df_output = pd.concat([df_output, dftemp], ignore_index=True)
    
    return df_output

# %% [markdown]
# ### GSSPECIES (species info)

# %%
# investigate GSSPECIES 
filetype_index = 3
species_files = [filetype_index + 5*n for n in range(4)]

for i in species_files:
    print_information(i)
# Out:
# GSSPECIES (4VSW)
#
# columns: ['SPEC', 'COMM', 'CODE', 'TSN']
# shape: (329, 4)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPEC    329 non-null    object
#  1   COMM    329 non-null    object
#  2   CODE    329 non-null    int64
#  3   TSN     0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 10.4+ KB
# None
#
#
#
# GSSPECIES (FALL)
#
# columns: ['SPEC', 'COMM', 'CODE', 'TSN']
# shape: (121, 4)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPEC    121 non-null    object
#  1   COMM    121 non-null    object
#  2   CODE    121 non-null    int64
#  3   TSN     0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.9+ KB
# None
#
#
#
# GSSPECIES (SPRING)
#
# columns: ['SPEC', 'COMM', 'CODE', 'TSN']
# shape: (476, 4)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPEC    476 non-null    object
#  1   COMM    476 non-null    object
#  2   CODE    476 non-null    int64
#  3   TSN     0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 15.0+ KB
# None
#
#
#
# GSSPECIES (SUMMER)
#
# columns: ['SPEC', 'COMM', 'CODE', 'TSN']
# shape: (811, 4)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SPEC    811 non-null    object
#  1   COMM    811 non-null    object
#  2   CODE    811 non-null    int64
#  3   TSN     0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 25.5+ KB
# None

# %%
# combine GSSPECIES files
df_species = combine_seasons(species_files)
df_species.shape
# Out:
# (1737, 6)

# %%
# check to see if SPEC and CODE always match
list_of_species = list(df_species.CODE.unique())
inconsistencies = []

for species_code in list_of_species:
    if len(df_species[df_species.CODE == species_code].SPEC.unique()) != 1:
        inconsistencies.append(species_code)

# looks good - all species have consistent codes, can merge and drop SEASON/FILE
inconsistencies
# Out:
# []

# %%
# confirm all species loop works
list_of_species = list(df_species.CODE.unique())
species_names = []

for species_code in list_of_species:
    if len(df_species[df_species.CODE == species_code].SPEC.unique()) == 1:
        species_names.append(df_species[df_species.CODE == species_code].COMM.reset_index(drop=True)[0])
        
# looks good
species_names[:10]
# Out:
# ["GRAY'S CUTTHROAT EEL",
#  'WOLF EELPOUT',
#  'SNIPE EEL',
#  'NORTHERN SAND LANCE',
#  'STOUT SAWPALATE',
#  'FISH DOCTOR',
#  'COMMON WOLF EEL',
#  'EELPOUT,NEWFOUNDLAND',
#  "LAVAL'S EELPOUT",
#  'SNAKE BLENNY']

# %%
# drop season and file columns and reindex
try:
    df_species.drop(['SEASON', 'FILE'], axis=1, inplace=True)
except:
    pass

df_species = df_species.drop_duplicates().sort_values('CODE').reset_index(drop=True)
df_species.head()
# Out:
#                        SPEC                COMM  CODE  TSN
# 0        BALISTES CAPRISCUS    GRAY TRIGGERFISH     3  NaN
# 1    STEPHANOLEPIS HISPIDUS  PLANEHEAD FILEFISH     6  NaN
# 2                BOTHUS SP.          BOTHUS SP.     8  NaN
# 3              GADUS MORHUA       COD(ATLANTIC)    10  NaN
# 4  MELANOGRAMMUS AEGLEFINUS             HADDOCK    11  NaN

# %%
# check that no codes are duplicated
sum(df_species.CODE.duplicated(keep=False))
# Out:
# 0

# %%
# every single TSN value is empty
# confirmed in Excel for 4 seasons
sum(df_species.TSN.isna())
# Out:
# 880

# %%
# drop TSN column
try:  # will only drop it once, in case cell is run twice
    df_species.drop('TSN', axis=1, inplace=True)
except:
    pass

# %%
# reindex
df_species = df_species.set_index('CODE', drop=False) # code left in place for ease
df_species.index.name = 'index'

# reorder columns
df_species = df_species[['CODE', 'COMM', 'SPEC']]

df_species.head()
# Out:
#        CODE                COMM                      SPEC
# index
# 3         3    GRAY TRIGGERFISH        BALISTES CAPRISCUS
# 6         6  PLANEHEAD FILEFISH    STEPHANOLEPIS HISPIDUS
# 8         8          BOTHUS SP.                BOTHUS SP.
# 10       10       COD(ATLANTIC)              GADUS MORHUA
# 11       11             HADDOCK  MELANOGRAMMUS AEGLEFINUS

# %% [markdown]
# ### GSMISSIONS (Missions and Vessels)

# %%
# investigate GSMISSIONS 
filetype_index = 4
mission_files = [filetype_index + 5*n for n in range(4)]

for i in mission_files:
    print_information(i)
# Out:
# GSMISSIONS (4VSW)
#
# columns: ['MISSION', 'VESEL', 'CRUNO', 'YEAR', 'SEASON']
# shape: (25, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  25 non-null     object
#  1   VESEL    25 non-null     object
#  2   CRUNO    25 non-null     int64
#  3   YEAR     25 non-null     int64
#  4   SEASON   25 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB
# None
#
#
#
# GSMISSIONS (FALL)
#
# columns: ['MISSION', 'VESEL', 'CRUNO', 'YEAR', 'SEASON']
# shape: (15, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  15 non-null     object
#  1   VESEL    15 non-null     object
#  2   CRUNO    15 non-null     int64
#  3   YEAR     15 non-null     int64
#  4   SEASON   15 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 728.0+ bytes
# None
#
#
#
# GSMISSIONS (SPRING)
#
# columns: ['MISSION', 'VESEL', 'CRUNO', 'YEAR', 'SEASON']
# shape: (57, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  57 non-null     object
#  1   VESEL    57 non-null     object
#  2   CRUNO    57 non-null     int64
#  3   YEAR     57 non-null     int64
#  4   SEASON   57 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.4+ KB
# None
#
#
#
# GSMISSIONS (SUMMER)
#
# columns: ['MISSION', 'VESEL', 'CRUNO', 'YEAR', 'SEASON']
# shape: (91, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  91 non-null     object
#  1   VESEL    91 non-null     object
#  2   CRUNO    91 non-null     int64
#  3   YEAR     91 non-null     int64
#  4   SEASON   91 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 3.7+ KB
# None

# %%
# combine GMISSIONS files
df_missions = combine_seasons(mission_files)
df_missions.shape
# Out:
# (188, 6)

# %%
df_missions.MISSION.value_counts().sort_values().tail()
# Out:
# NED2017020    1
# NED2015017    1
# NED2016016    1
# NED2006036    1
# NED1995217    2
# Name: MISSION, dtype: int64

# %%
df_missions[df_missions.MISSION == 'NED1995217']
# Out:
#        MISSION VESEL  CRUNO  YEAR  SEASON        FILE
# 9   NED1995217     N    217  1995    4VSW  GSMISSIONS
# 64  NED1995217     N    217  1995  SPRING  GSMISSIONS

# %%
# confirm that date and time are included in GSINF
print_information(2)
# Out:
# GSINF (4VSW)
#
# columns: ['MISSION', 'SETNO', 'SDATE', 'TIME', 'STRAT', 'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL', 'GEARDESC']
# shape: (2024, 17)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024 entries, 0 to 2023
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MISSION    2024 non-null   object
#  1   SETNO      2024 non-null   int64
#  2   SDATE      2024 non-null   object
#  3   TIME       2024 non-null   int64
#  4   STRAT      2024 non-null   int64
#  5   SLAT       2024 non-null   float64
#  6   SLONG      2024 non-null   float64
#  7   ELAT       1708 non-null   float64
#  8   ELONG      1708 non-null   float64
#  9   DUR        2024 non-null   int64
#  10  DIST       2024 non-null   float64
#  11  SPEED      2024 non-null   float64
#  12  DEPTH      2024 non-null   float64
#  13  SURF_TEMP  1701 non-null   float64
#  14  BOTT_TEMP  1638 non-null   float64
#  15  BOTT_SAL   1549 non-null   float64
#  16  GEARDESC   2024 non-null   object
# dtypes: float64(10), int64(4), object(3)
# memory usage: 268.9+ KB
# None

# %% [markdown]
# * without the season information, there are no inconsistent data
# * since date and time are included in GSINF, it is appropriate to:
#     * drop the season and file columns
#     * delete the duplicated row(s)

# %%
# drop season and file columns, drop duplicated missions
try:
    df_missions.drop(['SEASON', 'FILE'], axis=1, inplace=True)
    df_missions = df_missions.drop_duplicates()
except:
    pass

# %%
# sort and reset index
df_missions = df_missions.sort_values('MISSION').reset_index(drop=True)

df_missions.head()
# Out:
#       MISSION VESEL  CRUNO  YEAR
# 0  ATC1970175     A    175  1970
# 1  ATC1970176     A    176  1970
# 2  ATC1971188     A    188  1971
# 3  ATC1971189     A    189  1971
# 4  ATC1972200     A    200  1972

# %% [markdown]
# ### GSINF

# %%
# investigate GSINF 
filetype_index = 2
gsinf_files = [filetype_index + 5*n for n in range(4)]

for i in gsinf_files:
    print_information(i)
# Out:
# GSINF (4VSW)
#
# columns: ['MISSION', 'SETNO', 'SDATE', 'TIME', 'STRAT', 'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL', 'GEARDESC']
# shape: (2024, 17)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024 entries, 0 to 2023
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MISSION    2024 non-null   object
#  1   SETNO      2024 non-null   int64
#  2   SDATE      2024 non-null   object
#  3   TIME       2024 non-null   int64
#  4   STRAT      2024 non-null   int64
#  5   SLAT       2024 non-null   float64
#  6   SLONG      2024 non-null   float64
#  7   ELAT       1708 non-null   float64
#  8   ELONG      1708 non-null   float64
#  9   DUR        2024 non-null   int64
#  10  DIST       2024 non-null   float64
#  11  SPEED      2024 non-null   float64
#  12  DEPTH      2024 non-null   float64
#  13  SURF_TEMP  1701 non-null   float64
#  14  BOTT_TEMP  1638 non-null   float64
#  15  BOTT_SAL   1549 non-null   float64
#  16  GEARDESC   2024 non-null   object
# dtypes: float64(10), int64(4), object(3)
# memory usage: 268.9+ KB
# None
#
#
#
# GSINF (FALL)
#
# columns: ['MISSION', 'SETNO', 'SDATE', 'TIME', 'STRAT', 'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL', 'GEARDESC']
# shape: (1041, 17)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MISSION    1041 non-null   object
#  1   SETNO      1041 non-null   int64
#  2   SDATE      1041 non-null   object
#  3   TIME       1041 non-null   int64
#  4   STRAT      1041 non-null   int64
#  5   SLAT       1041 non-null   float64
#  6   SLONG      1041 non-null   float64
#  7   ELAT       0 non-null      float64
#  8   ELONG      0 non-null      float64
#  9   DUR        1041 non-null   int64
#  10  DIST       1041 non-null   float64
#  11  SPEED      1041 non-null   float64
#  12  DEPTH      1041 non-null   float64
#  13  SURF_TEMP  1037 non-null   float64
#  14  BOTT_TEMP  937 non-null    float64
#  15  BOTT_SAL   864 non-null    float64
#  16  GEARDESC   1041 non-null   object
# dtypes: float64(10), int64(4), object(3)
# memory usage: 138.4+ KB
# None
#
#
#
# GSINF (SPRING)
#
# columns: ['MISSION', 'SETNO', 'SDATE', 'TIME', 'STRAT', 'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL', 'GEARDESC']
# shape: (4146, 17)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4146 entries, 0 to 4145
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MISSION    4146 non-null   object
#  1   SETNO      4146 non-null   int64
#  2   SDATE      4146 non-null   object
#  3   TIME       4146 non-null   int64
#  4   STRAT      4146 non-null   object
#  5   SLAT       4146 non-null   float64
#  6   SLONG      4146 non-null   float64
#  7   ELAT       2953 non-null   float64
#  8   ELONG      2953 non-null   float64
#  9   DUR        4146 non-null   int64
#  10  DIST       4146 non-null   float64
#  11  SPEED      4146 non-null   float64
#  12  DEPTH      4146 non-null   float64
#  13  SURF_TEMP  2767 non-null   float64
#  14  BOTT_TEMP  2777 non-null   float64
#  15  BOTT_SAL   2717 non-null   float64
#  16  GEARDESC   4146 non-null   object
# dtypes: float64(10), int64(3), object(4)
# memory usage: 550.8+ KB
# None
#
#
#
# GSINF (SUMMER)
#
# columns: ['MISSION', 'SETNO', 'SDATE', 'TIME', 'STRAT', 'SLAT', 'SLONG', 'ELAT', 'ELONG', 'DUR', 'DIST', 'SPEED', 'DEPTH', 'SURF_TEMP', 'BOTT_TEMP', 'BOTT_SAL', 'GEARDESC']
# shape: (9434, 17)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9434 entries, 0 to 9433
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MISSION    9434 non-null   object
#  1   SETNO      9434 non-null   int64
#  2   SDATE      9434 non-null   object
#  3   TIME       9434 non-null   int64
#  4   STRAT      9434 non-null   object
#  5   SLAT       9434 non-null   float64
#  6   SLONG      9434 non-null   float64
#  7   ELAT       6432 non-null   float64
#  8   ELONG      6432 non-null   float64
#  9   DUR        9434 non-null   int64
#  10  DIST       9434 non-null   float64
#  11  SPEED      9434 non-null   float64
#  12  DEPTH      9430 non-null   float64
#  13  SURF_TEMP  8717 non-null   float64
#  14  BOTT_TEMP  8627 non-null   float64
#  15  BOTT_SAL   8619 non-null   float64
#  16  GEARDESC   9434 non-null   object
# dtypes: float64(10), int64(3), object(4)
# memory usage: 1.2+ MB
# None

# %%
# combine GSINF files
df_gsinf = combine_seasons(gsinf_files)
df_gsinf.shape
# Out:
# (16645, 19)

# %%
# need to convert dates and times to pandas datetimes
df_gsinf.dtypes
# Out:
# MISSION       object
# SETNO          int64
# SDATE         object
# TIME           int64
# STRAT         object
# SLAT         float64
# SLONG        float64
# ELAT         float64
# ELONG        float64
# DUR            int64
# DIST         float64
# SPEED        float64
# DEPTH        float64
# SURF_TEMP    float64
# BOTT_TEMP    float64
# BOTT_SAL     float64
# GEARDESC      object
# SEASON        object
# FILE          object
# dtype: object

# %%
df_gsinf.head()
# Out:
#       MISSION  SETNO       SDATE  TIME STRAT       SLAT      SLONG       ELAT  \
# 0  NED1997255     38  1997-03-15   614   402  45.541333 -58.122500  45.525167
# 1  NED1997255     39  1997-03-15   814   402  45.545667 -57.912500  45.568833
# 2  NED1997255     40  1997-03-15  1005   400  45.573333 -57.796333  45.549167
# 3  NED1997255     41  1997-03-15  1227   397  45.533500 -57.568833  45.509667
# 4  NED1997255     42  1997-03-15  1513   400  45.416333 -57.670167  45.394333
#
#        ELONG  DUR  DIST  SPEED   DEPTH  SURF_TEMP  BOTT_TEMP  BOTT_SAL  \
# 0 -58.087333   30  1.78   3.56  131.67       0.02       1.61    32.670
# 1 -57.934000   30  1.69   3.38  267.00       0.21       7.46    34.858
# 2 -57.775500   30  1.71   3.42  409.65       0.16       5.39    34.875
# 3 -57.539333   30  1.90   3.80  462.69       0.55       4.98    34.924
# 4 -57.642333   30  1.78   3.56  427.94        NaN        NaN       NaN
#
#             GEARDESC SEASON   FILE
# 0  Western IIA trawl   4VSW  GSINF
# 1  Western IIA trawl   4VSW  GSINF
# 2  Western IIA trawl   4VSW  GSINF
# 3  Western IIA trawl   4VSW  GSINF
# 4  Western IIA trawl   4VSW  GSINF

# %%
df_gsinf[['SDATE', 'TIME']]
# Out:
#             SDATE  TIME
# 0      1997-03-15   614
# 1      1997-03-15   814
# 2      1997-03-15  1005
# 3      1997-03-15  1227
# 4      1997-03-15  1513
# ...           ...   ...
# 16640  2020-08-06  1036
# 16641  2020-08-07    30
# 16642  2020-08-07   218
# 16643  2020-08-07   651
# 16644  2020-08-07  1052
#
# [16645 rows x 2 columns]

# %%
# getting the proper datetime formatting to convert using pd.to_datetime
df_gsinf['SDATE'].astype(str) + ' ' + \
(df_gsinf.TIME // 100).astype(str) + ':' + \
(df_gsinf.TIME % 100).astype(str).str.pad(width=2, side='left', fillchar='0')
# Out:
# 0         1997-03-15 6:14
# 1         1997-03-15 8:14
# 2        1997-03-15 10:05
# 3        1997-03-15 12:27
# 4        1997-03-15 15:13
#                ...
# 16640    2020-08-06 10:36
# 16641     2020-08-07 0:30
# 16642     2020-08-07 2:18
# 16643     2020-08-07 6:51
# 16644    2020-08-07 10:52
# Length: 16645, dtype: object

# %%
# index values using pandas datetime formatting
df_gsinf.index = pd.to_datetime(
    # datetime formatting
    df_gsinf['SDATE'].astype(str) + ' ' + \
    (df_gsinf.TIME // 100).astype(str) + ':' + \
    (df_gsinf.TIME % 100).astype(str).str.pad(width=2, side='left', fillchar='0')
)
df_gsinf.index.name = 'date and time'

# %%
# sort by index (date and time)
df_gsinf.sort_index(inplace=True)
df_gsinf.head(10)
# Out:
#                         MISSION  SETNO       SDATE  TIME STRAT       SLAT  \
# date and time
# 1970-07-06 18:25:00  ATC1970175      1  1970-07-06  1825   492  44.800000
# 1970-07-07 01:45:00  ATC1970175      3  1970-07-07   145   492  44.983333
# 1970-07-07 06:25:00  ATC1970175      4  1970-07-07   625   494  45.200000
# 1970-07-07 15:25:00  ATC1970175      6  1970-07-07  1525   494  45.300000
# 1970-07-07 18:15:00  ATC1970175      7  1970-07-07  1815   495  45.266667
# 1970-07-07 22:45:00  ATC1970175      2  1970-07-07  2245   493  45.066667
# 1970-07-08 02:15:00  ATC1970175      9  1970-07-08   215   490  44.833333
# 1970-07-08 06:45:00  ATC1970175     10  1970-07-08   645   492  44.716667
# 1970-07-08 13:15:00  ATC1970175     12  1970-07-08  1315   491  44.483333
# 1970-07-08 16:55:00  ATC1970175     13  1970-07-08  1655   490  44.133333
#
#                          SLONG  ELAT  ELONG  DUR  DIST  SPEED   DEPTH  \
# date and time
# 1970-07-06 18:25:00 -66.700000   NaN    NaN   30   2.3    4.6   85.95
# 1970-07-07 01:45:00 -65.916667   NaN    NaN   30   1.5    3.0  106.07
# 1970-07-07 06:25:00 -65.416667   NaN    NaN   30   2.5    5.0   58.52
# 1970-07-07 15:25:00 -65.150000   NaN    NaN   30   1.7    3.4   58.52
# 1970-07-07 18:15:00 -64.883333   NaN    NaN   30   1.0    2.0   51.21
# 1970-07-07 22:45:00 -66.200000   NaN    NaN   30   2.6    5.2   78.64
# 1970-07-08 02:15:00 -65.816667   NaN    NaN   30   1.5    3.0   91.44
# 1970-07-08 06:45:00 -66.466667   NaN    NaN   30   1.8    3.6  179.22
# 1970-07-08 13:15:00 -66.400000   NaN    NaN   30   1.6    3.2  186.54
# 1970-07-08 16:55:00 -66.566667   NaN    NaN   30   1.7    3.4   89.61
#
#                      SURF_TEMP  BOTT_TEMP  BOTT_SAL                GEARDESC  \
# date and time
# 1970-07-06 18:25:00        8.7       6.78     32.25  Yankee #36 otter trawl
# 1970-07-07 01:45:00       10.7       7.13     32.39  Yankee #36 otter trawl
# 1970-07-07 06:25:00        NaN       8.69     31.26  Yankee #36 otter trawl
# 1970-07-07 15:25:00       10.4       9.37     30.99  Yankee #36 otter trawl
# 1970-07-07 18:15:00       10.7       6.72     30.91  Yankee #36 otter trawl
# 1970-07-07 22:45:00        8.9       6.72     32.10  Yankee #36 otter trawl
# 1970-07-08 02:15:00       12.1       6.81     32.39  Yankee #36 otter trawl
# 1970-07-08 06:45:00       11.0       6.29     33.22  Yankee #36 otter trawl
# 1970-07-08 13:15:00        9.6       6.42     33.40  Yankee #36 otter trawl
# 1970-07-08 16:55:00       10.1       7.61     32.88  Yankee #36 otter trawl
#
#                      SEASON   FILE
# date and time
# 1970-07-06 18:25:00  SUMMER  GSINF
# 1970-07-07 01:45:00  SUMMER  GSINF
# 1970-07-07 06:25:00  SUMMER  GSINF
# 1970-07-07 15:25:00  SUMMER  GSINF
# 1970-07-07 18:15:00  SUMMER  GSINF
# 1970-07-07 22:45:00  SUMMER  GSINF
# 1970-07-08 02:15:00  SUMMER  GSINF
# 1970-07-08 06:45:00  SUMMER  GSINF
# 1970-07-08 13:15:00  SUMMER  GSINF
# 1970-07-08 16:55:00  SUMMER  GSINF

# %%
# now we have datetime funcitonality with the dataframe
# https://pandas.pydata.org/docs/reference/arrays.html#datetime-data

# EXAMPLE: all GSINF for missions on '1970-07-10'
df_gsinf[df_gsinf.index.date == pd.to_datetime('1970-07-10').date()]
# Out:
#                         MISSION  SETNO       SDATE  TIME STRAT       SLAT  \
# date and time
# 1970-07-10 03:05:00  ATC1970175     21  1970-07-10   305   483  42.466667
# 1970-07-10 07:15:00  ATC1970175     22  1970-07-10   715   483  42.483333
# 1970-07-10 10:55:00  ATC1970175     23  1970-07-10  1055   482  42.450000
# 1970-07-10 14:25:00  ATC1970175     24  1970-07-10  1425   480  42.733333
# 1970-07-10 20:15:00  ATC1970175     26  1970-07-10  2015   480  42.600000
# 1970-07-10 22:05:00  ATC1970175     20  1970-07-10  2205   482  42.633333
#
#                          SLONG  ELAT  ELONG  DUR  DIST  SPEED   DEPTH  \
# date and time
# 1970-07-10 03:05:00 -67.333333   NaN    NaN   30   1.7    3.4  343.81
# 1970-07-10 07:15:00 -66.700000   NaN    NaN   30   2.2    4.4  320.04
# 1970-07-10 10:55:00 -66.283333   NaN    NaN   30   1.8    3.6  246.89
# 1970-07-10 14:25:00 -66.100000   NaN    NaN   30   1.8    3.6   67.67
# 1970-07-10 20:15:00 -65.866667   NaN    NaN   30   2.0    4.0   84.12
# 1970-07-10 22:05:00 -66.833333   NaN    NaN   30   1.8    3.6  213.97
#
#                      SURF_TEMP  BOTT_TEMP  BOTT_SAL                GEARDESC  \
# date and time
# 1970-07-10 03:05:00       15.3       6.71     34.76  Yankee #36 otter trawl
# 1970-07-10 07:15:00       16.1       6.90     34.81  Yankee #36 otter trawl
# 1970-07-10 10:55:00       13.9       7.11     34.69  Yankee #36 otter trawl
# 1970-07-10 14:25:00        9.9       7.02     32.61  Yankee #36 otter trawl
# 1970-07-10 20:15:00       13.1       5.60     32.57  Yankee #36 otter trawl
# 1970-07-10 22:05:00       14.9       6.92     34.56  Yankee #36 otter trawl
#
#                      SEASON   FILE
# date and time
# 1970-07-10 03:05:00  SUMMER  GSINF
# 1970-07-10 07:15:00  SUMMER  GSINF
# 1970-07-10 10:55:00  SUMMER  GSINF
# 1970-07-10 14:25:00  SUMMER  GSINF
# 1970-07-10 20:15:00  SUMMER  GSINF
# 1970-07-10 22:05:00  SUMMER  GSINF

# %%
# there are no duplicates, therefore we can drop 'SEASON' and 'FILE'
sum(df_gsinf.drop(['SEASON', 'FILE'], axis=1).duplicated(keep=False))
# Out:
# 0

# %%
# drop 'SEASON' and 'FILE' columns
# NOTE: not reindexed because index is datatime for the entry
try:  # only drop it once
    df_gsinf.drop(['SEASON', 'FILE'], axis=1, inplace=True)
except:
    pass

df_gsinf.head()
# Out:
#                         MISSION  SETNO       SDATE  TIME STRAT       SLAT  \
# date and time
# 1970-07-06 18:25:00  ATC1970175      1  1970-07-06  1825   492  44.800000
# 1970-07-07 01:45:00  ATC1970175      3  1970-07-07   145   492  44.983333
# 1970-07-07 06:25:00  ATC1970175      4  1970-07-07   625   494  45.200000
# 1970-07-07 15:25:00  ATC1970175      6  1970-07-07  1525   494  45.300000
# 1970-07-07 18:15:00  ATC1970175      7  1970-07-07  1815   495  45.266667
#
#                          SLONG  ELAT  ELONG  DUR  DIST  SPEED   DEPTH  \
# date and time
# 1970-07-06 18:25:00 -66.700000   NaN    NaN   30   2.3    4.6   85.95
# 1970-07-07 01:45:00 -65.916667   NaN    NaN   30   1.5    3.0  106.07
# 1970-07-07 06:25:00 -65.416667   NaN    NaN   30   2.5    5.0   58.52
# 1970-07-07 15:25:00 -65.150000   NaN    NaN   30   1.7    3.4   58.52
# 1970-07-07 18:15:00 -64.883333   NaN    NaN   30   1.0    2.0   51.21
#
#                      SURF_TEMP  BOTT_TEMP  BOTT_SAL                GEARDESC
# date and time
# 1970-07-06 18:25:00        8.7       6.78     32.25  Yankee #36 otter trawl
# 1970-07-07 01:45:00       10.7       7.13     32.39  Yankee #36 otter trawl
# 1970-07-07 06:25:00        NaN       8.69     31.26  Yankee #36 otter trawl
# 1970-07-07 15:25:00       10.4       9.37     30.99  Yankee #36 otter trawl
# 1970-07-07 18:15:00       10.7       6.72     30.91  Yankee #36 otter trawl

# %% [markdown]
# ### GSCAT

# %%
# investigate GSCAT  
filetype_index = 0
gscat_files = [filetype_index + 5*n for n in range(4)]

for i in gscat_files:
    print_information(i)
# Out:
# GSCAT (4VSW)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'TOTWGT', 'TOTNO']
# shape: (26018, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26018 entries, 0 to 26017
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  26018 non-null  object
#  1   SETNO    26018 non-null  int64
#  2   SPEC     26018 non-null  int64
#  3   TOTWGT   26018 non-null  float64
#  4   TOTNO    26018 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1016.5+ KB
# None
#
#
#
# GSCAT (FALL)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'TOTWGT', 'TOTNO']
# shape: (11010, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11010 entries, 0 to 11009
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  11010 non-null  object
#  1   SETNO    11010 non-null  int64
#  2   SPEC     11010 non-null  int64
#  3   TOTWGT   11010 non-null  int64
#  4   TOTNO    11010 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 430.2+ KB
# None
#
#
#
# GSCAT (SPRING)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'TOTWGT', 'TOTNO']
# shape: (55776, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55776 entries, 0 to 55775
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MISSION  55776 non-null  object
#  1   SETNO    55776 non-null  int64
#  2   SPEC     55776 non-null  int64
#  3   TOTWGT   55776 non-null  float64
#  4   TOTNO    55776 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ MB
# None
#
#
#
# GSCAT (SUMMER)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'TOTWGT', 'TOTNO']
# shape: (139416, 5)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139416 entries, 0 to 139415
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   MISSION  139416 non-null  object
#  1   SETNO    139416 non-null  int64
#  2   SPEC     139416 non-null  int64
#  3   TOTWGT   139416 non-null  float64
#  4   TOTNO    139416 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 5.3+ MB
# None

# %%
# combine GSCAT files
df_gscat = combine_seasons(gscat_files)
df_gscat.shape
# Out:
# (232220, 7)

# %%
df_gscat.sort_values(['MISSION', 'SETNO']).head(10)
# Out:
#            MISSION  SETNO  SPEC  TOTWGT  TOTNO  SEASON   FILE
# 92804   ATC1970175      1    10    59.0     12  SUMMER  GSCAT
# 98347   ATC1970175      1    11    10.0      4  SUMMER  GSCAT
# 104229  ATC1970175      1    12    19.0     19  SUMMER  GSCAT
# 110099  ATC1970175      1    14     0.0      4  SUMMER  GSCAT
# 125894  ATC1970175      1    40     6.0     17  SUMMER  GSCAT
# 143380  ATC1970175      1    60     7.0     18  SUMMER  GSCAT
# 147365  ATC1970175      1    62     0.0      1  SUMMER  GSCAT
# 148953  ATC1970175      1    70     0.0      1  SUMMER  GSCAT
# 154714  ATC1970175      1   201     6.0      2  SUMMER  GSCAT
# 162606  ATC1970175      1   220    14.0      7  SUMMER  GSCAT

# %%
# check for duplicates
sum(df_gscat.drop(['SEASON', 'FILE'], axis=1).duplicated(keep=False))
# Out:
# 0

# %%
df_gscat.head()
# Out:
#       MISSION  SETNO  SPEC  TOTWGT  TOTNO SEASON   FILE
# 0  NED1988098      1    10  13.000     17   4VSW  GSCAT
# 1  NED1989117      1    10   5.000     65   4VSW  GSCAT
# 2  NED1992166      1    10   4.000      7   4VSW  GSCAT
# 3  NED1993182      1    10   1.000     10   4VSW  GSCAT
# 4  NED1999872      1    10   0.115      2   4VSW  GSCAT

# %%
# drop 'SEASON' and 'FILE' and reset index

try:  # only drop columns once
    df_gscat.drop(['SEASON', 'FILE'], axis=1, inplace=True).reset_index(drop=True)
except:
    pass

df_gscat.head()
# Out:
#       MISSION  SETNO  SPEC  TOTWGT  TOTNO
# 0  NED1988098      1    10  13.000     17
# 1  NED1989117      1    10   5.000     65
# 2  NED1992166      1    10   4.000      7
# 3  NED1993182      1    10   1.000     10
# 4  NED1999872      1    10   0.115      2

# %% [markdown]
# ### GSDET

# %%
# investigate GSDET
filetype_index = 1
gsdet_files = [filetype_index + 5*n for n in range(4)]

for i in gsdet_files:
    print_information(i)
# Out:
# GSDET (4VSW)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 'SPECIMEN_ID']
# shape: (187974, 9)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187974 entries, 0 to 187973
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MISSION      187974 non-null  object
#  1   SETNO        187974 non-null  int64
#  2   SPEC         187974 non-null  int64
#  3   FLEN         187974 non-null  int64
#  4   FWT          96207 non-null   float64
#  5   MATURITY     18922 non-null   object
#  6   SEX          148096 non-null  object
#  7   AGE          14053 non-null   float64
#  8   SPECIMEN_ID  0 non-null       float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.9+ MB
# None
#
#
#
# GSDET (FALL)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 'SPECIMEN_ID']
# shape: (129685, 9)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129685 entries, 0 to 129684
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MISSION      129685 non-null  object
#  1   SETNO        129685 non-null  int64
#  2   SPEC         129685 non-null  int64
#  3   FLEN         129685 non-null  int64
#  4   FWT          88133 non-null   float64
#  5   MATURITY     66503 non-null   object
#  6   SEX          129684 non-null  object
#  7   AGE          39887 non-null   float64
#  8   SPECIMEN_ID  0 non-null       float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 8.9+ MB
# None
#
#
#
# GSDET (SPRING)
# C:\Users\Kevin\AppData\Local\Temp/ipykernel_11828/711337687.py:6: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   print_information(i)
# columns: ['MISSION', 'SETNO', 'SPEC', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 'SPECIMEN_ID']
# shape: (594518, 9)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594518 entries, 0 to 594517
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MISSION      594518 non-null  object
#  1   SETNO        594518 non-null  int64
#  2   SPEC         594518 non-null  int64
#  3   FLEN         594518 non-null  int64
#  4   FWT          227982 non-null  float64
#  5   MATURITY     118806 non-null  object
#  6   SEX          385788 non-null  object
#  7   AGE          81247 non-null   float64
#  8   SPECIMEN_ID  200925 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 40.8+ MB
# None
#
#
#
# GSDET (SUMMER)
#
# columns: ['MISSION', 'SETNO', 'SPEC', 'FLEN', 'FWT', 'MATURITY', 'SEX', 'AGE', 'SPECIMEN_ID']
# shape: (1385852, 9)
#
# info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385852 entries, 0 to 1385851
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   MISSION      1385852 non-null  object
#  1   SETNO        1385852 non-null  int64
#  2   SPEC         1385852 non-null  int64
#  3   FLEN         1385851 non-null  float64
#  4   FWT          738947 non-null   float64
#  5   MATURITY     220482 non-null   object
#  6   SEX          1017183 non-null  object
#  7   AGE          210325 non-null   float64
#  8   SPECIMEN_ID  399858 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 95.2+ MB
# None

# %% [markdown]
# ##### GSDET (SPRING): DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#     need to add a dtype kwarg to the combine_seasons() function
#     could use **kwargs, but dtype={} seems less prone to error

# %%
# combine GSDET files
df_gsdet = combine_seasons(gsdet_files, dtype={'MATURITY':object, 'SEX':object})
df_gsdet.shape
# Out:
# (2298029, 11)

# %%
df_gsdet.head(10)
# Out:
#       MISSION  SETNO  SPEC  FLEN     FWT MATURITY      SEX  AGE  SPECIMEN_ID  \
# 0  NED1999872     90    14  15.0    19.0      NaN  UNKNOWN  NaN          NaN
# 1  NED1995217    108    10  43.0     NaN      NaN  UNKNOWN  NaN          NaN
# 2  NED1986060     45    11  51.0  1300.0      NaN  UNKNOWN  NaN          NaN
# 3  NED1986060      7    11  46.0  1000.0      NaN  UNKNOWN  NaN          NaN
# 4  NED1987078     82    40  11.0     NaN      NaN  UNKNOWN  NaN          NaN
# 5  NED1987078     51   300  26.0     NaN      NaN  UNKNOWN  NaN          NaN
# 6  NED1994201     96    11  42.0     NaN      NaN  UNKNOWN  NaN          NaN
# 7  NED1997255     33    41   8.0     2.0      NaN  UNKNOWN  NaN          NaN
# 8  NED2000966     10    41  14.0     NaN      NaN  UNKNOWN  NaN          NaN
# 9  NED1989117     36    60  33.0     NaN      NaN  UNKNOWN  NaN          NaN
#
#   SEASON   FILE
# 0   4VSW  GSDET
# 1   4VSW  GSDET
# 2   4VSW  GSDET
# 3   4VSW  GSDET
# 4   4VSW  GSDET
# 5   4VSW  GSDET
# 6   4VSW  GSDET
# 7   4VSW  GSDET
# 8   4VSW  GSDET
# 9   4VSW  GSDET

# %%
# check for duplicates
sum(df_gsdet.drop(['SEASON', 'FILE'], axis=1).duplicated(keep=False))
# Out:
# 151158

# %%
# check for duplicates without the seasons/files noted
sum(df_gsdet.duplicated(keep=False))
# Out:
# 151158

# %% [markdown]
# ### Many repeated rows... why?
# ##### BEST GUESS: these are not duplicates, they are samples with the same characteristics
#
# ##### checked this, no matches:
#     check individual files for repeated rows
#         maybe these coincide with joins to other tables (database not completely normalised?)
#             if so, deleting all of the repeats and then joining properly should result in the same number of total rows

# %% [markdown]
# ##### how many duplicates in each file?

# %%
gsdet0 = pd.read_csv(all_files[gsdet_files[0]], dtype={'MATURITY':object, 'SEX':object})
sum(gsdet0.duplicated(keep=False))
# Out:
# 719

# %%
gsdet1 = pd.read_csv(all_files[gsdet_files[1]], dtype={'MATURITY':object, 'SEX':object})
sum(gsdet1.duplicated(keep=False))
# Out:
# 10975

# %%
gsdet2 = pd.read_csv(all_files[gsdet_files[2]], dtype={'MATURITY':object, 'SEX':object})
sum(gsdet2.duplicated(keep=False))
# Out:
# 45111

# %%
gsdet3 = pd.read_csv(all_files[gsdet_files[3]], dtype={'MATURITY':object, 'SEX':object})
sum(gsdet3.duplicated(keep=False))
# Out:
# 94353

# %% [markdown]
# ##### what is getting duplicated?

# %%
df_gsdet[df_gsdet.duplicated(keep=False)].sort_values(df_gsdet.columns.tolist()).head(20)
# Out:
#             MISSION  SETNO  SPEC  FLEN     FWT    MATURITY      SEX  AGE  \
# 994886   ATC1970175      1    60  30.0   440.0         NaN  UNKNOWN  NaN
# 1004723  ATC1970175      1    60  30.0   440.0         NaN  UNKNOWN  NaN
# 1044091  ATC1970175      1    60  30.0   440.0         NaN  UNKNOWN  NaN
# 1047370  ATC1970175      1    60  30.0   440.0         NaN  UNKNOWN  NaN
# 1018839  ATC1970175      2    10  61.0     NaN         NaN  UNKNOWN  NaN
# 1036336  ATC1970175      2    10  61.0     NaN         NaN  UNKNOWN  NaN
# 1516956  ATC1970175      2    14  26.0   100.0  Ripening 1   FEMALE  NaN
# 1778172  ATC1970175      2    14  26.0   100.0  Ripening 1   FEMALE  NaN
# 952304   ATC1970175      2    41  52.0  1100.0         NaN  UNKNOWN  NaN
# 965084   ATC1970175      2    41  52.0  1100.0         NaN  UNKNOWN  NaN
# 1568453  ATC1970175      2   201  15.0    25.0         NaN   FEMALE  NaN
# 1745603  ATC1970175      2   201  15.0    25.0         NaN   FEMALE  NaN
# 1602217  ATC1970175      6   220  49.0   625.0  Recovering   FEMALE  NaN
# 1781102  ATC1970175      6   220  49.0   625.0  Recovering   FEMALE  NaN
# 1606110  ATC1970175      7   220  62.0   950.0         NaN   FEMALE  NaN
# 1623813  ATC1970175      7   220  62.0   950.0         NaN   FEMALE  NaN
# 1566717  ATC1970175      7   220  69.0  1400.0         NaN   FEMALE  NaN
# 1743895  ATC1970175      7   220  69.0  1400.0         NaN   FEMALE  NaN
# 1623807  ATC1970175      7   220  70.0  1500.0         NaN   FEMALE  NaN
# 1655316  ATC1970175      7   220  70.0  1500.0         NaN   FEMALE  NaN
#
#          SPECIMEN_ID  SEASON   FILE
# 994886           NaN  SUMMER  GSDET
# 1004723          NaN  SUMMER  GSDET
# 1044091          NaN  SUMMER  GSDET
# 1047370          NaN  SUMMER  GSDET
# 1018839          NaN  SUMMER  GSDET
# 1036336          NaN  SUMMER  GSDET
# 1516956          NaN  SUMMER  GSDET
# 1778172          NaN  SUMMER  GSDET
# 952304           NaN  SUMMER  GSDET
# 965084           NaN  SUMMER  GSDET
# 1568453          NaN  SUMMER  GSDET
# 1745603          NaN  SUMMER  GSDET
# 1602217          NaN  SUMMER  GSDET
# 1781102          NaN  SUMMER  GSDET
# 1606110          NaN  SUMMER  GSDET
# 1623813          NaN  SUMMER  GSDET
# 1566717          NaN  SUMMER  GSDET
# 1743895          NaN  SUMMER  GSDET
# 1623807          NaN  SUMMER  GSDET
# 1655316          NaN  SUMMER  GSDET

# %% [markdown]
# ##### Which other file duplicates the same entries?
#     * not SPECIES
#     * not MISSIONS
#     * not GSINF
#     * not GSCAT

# %%
# NOT SPECIES
df_species[df_species.CODE == 60]
# Out:
#        CODE               COMM             SPEC
# index
# 60       60  HERRING(ATLANTIC)  CLUPEA HARENGUS

# %%
# NOT MISSIONS
df_missions[df_missions.MISSION == 'ATC1970175']
# Out:
#       MISSION VESEL  CRUNO  YEAR
# 0  ATC1970175     A    175  1970

# %%
# NOT GSINF

df_gsinf[(df_gsinf['MISSION'] == 'ATC1970175') & (df_gsinf['SETNO'] == 1)]
# Out:
#                         MISSION  SETNO       SDATE  TIME STRAT  SLAT  SLONG  \
# date and time
# 1970-07-06 18:25:00  ATC1970175      1  1970-07-06  1825   492  44.8  -66.7
#
#                      ELAT  ELONG  DUR  DIST  SPEED  DEPTH  SURF_TEMP  \
# date and time
# 1970-07-06 18:25:00   NaN    NaN   30   2.3    4.6  85.95        8.7
#
#                      BOTT_TEMP  BOTT_SAL                GEARDESC
# date and time
# 1970-07-06 18:25:00       6.78     32.25  Yankee #36 otter trawl

# %%
# GSCAT might be the answer (spoiler: no)

df_gscat[(df_gscat['MISSION'] == 'ATC1970175') & (df_gscat['SETNO'] == 1)]
# Out:
#            MISSION  SETNO  SPEC  TOTWGT  TOTNO
# 92804   ATC1970175      1    10    59.0     12
# 98347   ATC1970175      1    11    10.0      4
# 104229  ATC1970175      1    12    19.0     19
# 110099  ATC1970175      1    14     0.0      4
# 125894  ATC1970175      1    40     6.0     17
# 143380  ATC1970175      1    60     7.0     18
# 147365  ATC1970175      1    62     0.0      1
# 148953  ATC1970175      1    70     0.0      1
# 154714  ATC1970175      1   201     6.0      2
# 162606  ATC1970175      1   220    14.0      7
# 171046  ATC1970175      1   320     1.0      1
# 180262  ATC1970175      1   621     0.0      1
# 181511  ATC1970175      1   640     2.0      4
# 187975  ATC1970175      1  2210     0.0     30

# %%
# why are there 4 repeated rows in GSDET, but 14 in GSCAT?
df_gscat[(df_gscat['MISSION'] == 'ATC1970175') & (df_gscat['SETNO'] == 1)].shape
# Out:
# (14, 5)

# %%
# check GSCAT also filtering by species
df_gscat[(df_gscat['MISSION'] == 'ATC1970175') & (df_gscat['SETNO'] == 1) & (df_gscat['SPEC'] == 60)]

# NOT GSCAT
# Out:
#            MISSION  SETNO  SPEC  TOTWGT  TOTNO
# 143380  ATC1970175      1    60     7.0     18

# %%
# how many rows of GSDET match the above query?
df_gsdet[(df_gsdet['MISSION'] == 'ATC1970175') & (df_gsdet['SETNO'] == 1)].shape
# Out:
# (89, 11)

# %%
df_gsdet[(df_gsdet['MISSION'] == 'ATC1970175') & (df_gsdet['SETNO'] == 1)]
# Out:
#             MISSION  SETNO  SPEC  FLEN     FWT MATURITY      SEX  AGE  \
# 942393   ATC1970175      1    60  30.0   500.0      NaN  UNKNOWN  NaN
# 967115   ATC1970175      1    62  29.0     NaN      NaN  UNKNOWN  NaN
# 976703   ATC1970175      1   621  24.0    60.0      NaN  UNKNOWN  NaN
# 981865   ATC1970175      1    60  30.0   460.0      NaN  UNKNOWN  NaN
# 986462   ATC1970175      1   320  34.0   860.0      NaN  UNKNOWN  NaN
# ...             ...    ...   ...   ...     ...      ...      ...  ...
# 1652413  ATC1970175      1    12  91.0  7100.0      NaN   FEMALE  NaN
# 1698089  ATC1970175      1    40  38.0   475.0  Resting   FEMALE  6.0
# 1803350  ATC1970175      1    11  67.0  2800.0  Resting   FEMALE  7.0
# 1835302  ATC1970175      1   220  55.0     NaN      NaN   FEMALE  NaN
# 1835303  ATC1970175      1   220  58.0     NaN      NaN   FEMALE  NaN
#
#          SPECIMEN_ID  SEASON   FILE
# 942393           NaN  SUMMER  GSDET
# 967115           NaN  SUMMER  GSDET
# 976703           NaN  SUMMER  GSDET
# 981865           NaN  SUMMER  GSDET
# 986462           NaN  SUMMER  GSDET
# ...              ...     ...    ...
# 1652413          NaN  SUMMER  GSDET
# 1698089          NaN  SUMMER  GSDET
# 1803350          NaN  SUMMER  GSDET
# 1835302          NaN  SUMMER  GSDET
# 1835303          NaN  SUMMER  GSDET
#
# [89 rows x 11 columns]

# %%
df_gsdet[(df_gsdet['MISSION'] == 'ATC1970175') & (df_gsdet['SETNO'] == 1) & (df_gsdet['SPEC'] == 60)]
# Out:
#             MISSION  SETNO  SPEC  FLEN    FWT MATURITY      SEX  AGE  \
# 942393   ATC1970175      1    60  30.0  500.0      NaN  UNKNOWN  NaN
# 981865   ATC1970175      1    60  30.0  460.0      NaN  UNKNOWN  NaN
# 994886   ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN
# 1004723  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN
# 1004730  ATC1970175      1    60  29.0  380.0      NaN  UNKNOWN  NaN
# 1014568  ATC1970175      1    60  30.0  450.0      NaN  UNKNOWN  NaN
# 1021232  ATC1970175      1    60  33.0  570.0      NaN  UNKNOWN  NaN
# 1027684  ATC1970175      1    60  26.0  300.0      NaN  UNKNOWN  NaN
# 1030972  ATC1970175      1    60  27.0  280.0      NaN  UNKNOWN  NaN
# 1034248  ATC1970175      1    60  27.0  300.0      NaN  UNKNOWN  NaN
# 1034254  ATC1970175      1    60  24.0  230.0      NaN  UNKNOWN  NaN
# 1037527  ATC1970175      1    60  31.0  500.0      NaN  UNKNOWN  NaN
# 1039100  ATC1970175      1    60  26.0  270.0      NaN  UNKNOWN  NaN
# 1040810  ATC1970175      1    60  31.0  510.0      NaN  UNKNOWN  NaN
# 1042022  ATC1970175      1    60  29.0  420.0      NaN  UNKNOWN  NaN
# 1044091  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN
# 1046647  ATC1970175      1    60  25.0  230.0      NaN  UNKNOWN  NaN
# 1047370  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN
#
#          SPECIMEN_ID  SEASON   FILE
# 942393           NaN  SUMMER  GSDET
# 981865           NaN  SUMMER  GSDET
# 994886           NaN  SUMMER  GSDET
# 1004723          NaN  SUMMER  GSDET
# 1004730          NaN  SUMMER  GSDET
# 1014568          NaN  SUMMER  GSDET
# 1021232          NaN  SUMMER  GSDET
# 1027684          NaN  SUMMER  GSDET
# 1030972          NaN  SUMMER  GSDET
# 1034248          NaN  SUMMER  GSDET
# 1034254          NaN  SUMMER  GSDET
# 1037527          NaN  SUMMER  GSDET
# 1039100          NaN  SUMMER  GSDET
# 1040810          NaN  SUMMER  GSDET
# 1042022          NaN  SUMMER  GSDET
# 1044091          NaN  SUMMER  GSDET
# 1046647          NaN  SUMMER  GSDET
# 1047370          NaN  SUMMER  GSDET

# %%
df_gsdet[(df_gsdet['MISSION'] == 'ATC1970175') & (df_gsdet['SETNO'] == 1) & (df_gsdet['SPEC'] == 60)].shape
# Out:
# (18, 11)

# %% [markdown]
# ### MY HYPOTHESIS:
# ##### These rows aren't duplicates. There are multiple specimen with identical:
#     SPEC	FLEN	FWT	MATURITY	SEX	AGE	SPECIMEN_ID
#
# Often, the fact that a few fields are NULL allow for easier match.
#
# ### I.E., THESE ARE NOT DUPLICATE ROWS (they just have the same value)

# %%
# final cleaning for GSDET, 
# delete 'FILE' column
# KEEP 'SEASON' column for reference
# reindex, but do not delete duplicates

try:  # only drop columns once
    df_gsdet.drop('FILE', axis=1, inplace=True)
    df_gsdet = df_gsdet.sort_values(['MISSION', 'SETNO', 'SPEC', 'FLEN', 'FWT']).reset_index(drop=True)
except:
    pass

df_gsdet.head()
# Out:
#       MISSION  SETNO  SPEC  FLEN     FWT  MATURITY     SEX  AGE  SPECIMEN_ID  \
# 0  ATC1970175      1    10  28.0   220.0  Immature    MALE  2.0          NaN
# 1  ATC1970175      1    10  58.0  2000.0   Resting  FEMALE  NaN          NaN
# 2  ATC1970175      1    10  64.0  3000.0  Immature  FEMALE  NaN          NaN
# 3  ATC1970175      1    10  68.0  3600.0   Resting    MALE  4.0          NaN
# 4  ATC1970175      1    10  69.0  3200.0   Resting    MALE  5.0          NaN
#
#    SEASON
# 0  SUMMER
# 1  SUMMER
# 2  SUMMER
# 3  SUMMER
# 4  SUMMER

# %%
# confirm previous query to check index numbering and look for duplicates
# looks like it is working correctly
df_gsdet[(df_gsdet['MISSION'] == 'ATC1970175') & (df_gsdet['SETNO'] == 1) & (df_gsdet['SPEC'] == 60)]
# Out:
#        MISSION  SETNO  SPEC  FLEN    FWT MATURITY      SEX  AGE  SPECIMEN_ID  \
# 56  ATC1970175      1    60  24.0  230.0      NaN  UNKNOWN  NaN          NaN
# 57  ATC1970175      1    60  25.0  230.0      NaN  UNKNOWN  NaN          NaN
# 58  ATC1970175      1    60  26.0  270.0      NaN  UNKNOWN  NaN          NaN
# 59  ATC1970175      1    60  26.0  300.0      NaN  UNKNOWN  NaN          NaN
# 60  ATC1970175      1    60  27.0  280.0      NaN  UNKNOWN  NaN          NaN
# 61  ATC1970175      1    60  27.0  300.0      NaN  UNKNOWN  NaN          NaN
# 62  ATC1970175      1    60  29.0  380.0      NaN  UNKNOWN  NaN          NaN
# 63  ATC1970175      1    60  29.0  420.0      NaN  UNKNOWN  NaN          NaN
# 64  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN          NaN
# 65  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN          NaN
# 66  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN          NaN
# 67  ATC1970175      1    60  30.0  440.0      NaN  UNKNOWN  NaN          NaN
# 68  ATC1970175      1    60  30.0  450.0      NaN  UNKNOWN  NaN          NaN
# 69  ATC1970175      1    60  30.0  460.0      NaN  UNKNOWN  NaN          NaN
# 70  ATC1970175      1    60  30.0  500.0      NaN  UNKNOWN  NaN          NaN
# 71  ATC1970175      1    60  31.0  500.0      NaN  UNKNOWN  NaN          NaN
# 72  ATC1970175      1    60  31.0  510.0      NaN  UNKNOWN  NaN          NaN
# 73  ATC1970175      1    60  33.0  570.0      NaN  UNKNOWN  NaN          NaN
#
#     SEASON
# 56  SUMMER
# 57  SUMMER
# 58  SUMMER
# 59  SUMMER
# 60  SUMMER
# 61  SUMMER
# 62  SUMMER
# 63  SUMMER
# 64  SUMMER
# 65  SUMMER
# 66  SUMMER
# 67  SUMMER
# 68  SUMMER
# 69  SUMMER
# 70  SUMMER
# 71  SUMMER
# 72  SUMMER
# 73  SUMMER

# %%
df_gsdet.shape
# Out:
# (2298029, 10)

# %% [markdown]
# # DEFINE DATABASE, EXPORT, JOIN TABLES
